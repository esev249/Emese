# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import statistics

# %%
df = pd.read_excel('all_results_table2.xlsx')


print(df)
# Out:
#                          Name  Data set  RatID  StudyDay Condition  Treatment  \
# 0    Rat1_SD1_CN_4_posttrial2  OS_Basic      1         1        CN          4
# 1    Rat1_SD1_CN_4_posttrial4  OS_Basic      1         1        CN          4
# 2    Rat3_SD1_CN_4_posttrial4  OS_Basic      3         1        CN          4
# 3    Rat3_SD1_CN_4_posttrial5  OS_Basic      3         1        CN          4
# 4    Rat4_SD1_CN_4_posttrial2  OS_Basic      4         1        CN          4
# ..                        ...       ...    ...       ...       ...        ...
# 183  Rat1_SD2_OR_4_posttrial4  OS_Basic      1         2        OR          4
# 184  Rat3_SD1_OR_4_posttrial4  OS_Basic      3         1        OR          4
# 185  Rat3_SD1_OR_4_posttrial5  OS_Basic      3         1        OR          4
# 186  Rat4_SD3_OR_4_posttrial4  OS_Basic      4         3        OR          4
# 187  Rat4_SD3_OR_4_posttrial5  OS_Basic      4         3        OR          4
#
# ...

# %%
# per method:
frequency_pcn = df.iloc[0:24, 12]
frequency_tcn = df.iloc[24:48, 12]
frequency_phc = df.iloc[48:68, 12]
frequency_thc = df.iloc[68:92, 12]
frequency_pod = df.iloc[92:116, 12]
frequency_tod = df.iloc[116:140, 12]
frequency_por = df.iloc[140:164, 12]
frequency_tor = df.iloc[164:188, 12]

COH_pcn = df.iloc[0:24, 13]
COH_tcn = df.iloc[24:48, 13]
COH_phc = df.iloc[48:68, 13]
COH_thc = df.iloc[68:92, 13]
COH_pod = df.iloc[92:116, 13]
COH_tod = df.iloc[116:140, 13]
COH_por = df.iloc[140:164, 13]
COH_tor = df.iloc[164:188, 13]

iCOH_pcn = df.iloc[0:24, 15]
iCOH_tcn = df.iloc[24:48, 15]
iCOH_phc = df.iloc[48:68, 15]
iCOH_thc = df.iloc[68:92, 15]
iCOH_pod = df.iloc[92:116, 15]
iCOH_tod = df.iloc[116:140, 15]
iCOH_por = df.iloc[140:164, 15]
iCOH_tor = df.iloc[164:188, 15]

PLI_pcn = df.iloc[0:24, 17]
PLI_tcn = df.iloc[24:48, 17]
PLI_phc = df.iloc[48:68, 17]
PLI_thc = df.iloc[68:92, 17]
PLI_pod = df.iloc[92:116, 17]
PLI_tod = df.iloc[116:140, 17]
PLI_por = df.iloc[140:164, 17]
PLI_tor = df.iloc[164:188, 17]

wPLI_pcn = df.iloc[0:24, 19]
wPLI_tcn = df.iloc[24:48, 19]
wPLI_phc = df.iloc[48:68, 19]
wPLI_thc = df.iloc[68:92, 19]
wPLI_pod = df.iloc[92:116, 19]
wPLI_tod = df.iloc[116:140, 19]
wPLI_por = df.iloc[140:164, 19]
wPLI_tor = df.iloc[164:188, 19]

DSPLI_pcn = df.iloc[0:24, 21]
DSPLI_tcn = df.iloc[24:48, 21]
DSPLI_phc = df.iloc[48:68, 21]
DSPLI_thc = df.iloc[68:92, 21]
DSPLI_pod = df.iloc[92:116, 21]
DSPLI_tod = df.iloc[116:140, 21]
DSPLI_por = df.iloc[140:164, 21]
DSPLI_tor = df.iloc[164:188, 21]

wDSPLI_pcn = df.iloc[0:24, 23]
wDSPLI_tcn = df.iloc[24:48, 23]
wDSPLI_phc = df.iloc[48:68, 23]
wDSPLI_thc = df.iloc[68:92, 23]
wDSPLI_pod = df.iloc[92:116, 23]
wDSPLI_tod = df.iloc[116:140, 23]
wDSPLI_por = df.iloc[140:164, 23]
wDSPLI_tor = df.iloc[164:188, 23]

PPC_pcn = df.iloc[0:24, 25]
PPC_tcn = df.iloc[24:48, 25]
PPC_phc = df.iloc[48:68, 25]
PPC_thc = df.iloc[68:92, 25]
PPC_pod = df.iloc[92:116, 25]
PPC_tod = df.iloc[116:140, 25]
PPC_por = df.iloc[140:164, 25]
PPC_tor = df.iloc[164:188, 25]

# %%
print(df.iloc[24:30, 13])
# Out:
# 24    0.246519
# 25    0.314968
# 26    0.219588
# 27    0.265805
# 28    0.255256
# 29    0.202569
# Name: COH, dtype: float64

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_COH_pcn_delta = statistics.mean(df.iloc[0:6, 13])
mean_COH_pcn_theta = statistics.mean(df.iloc[6:12, 13])
mean_COH_pcn_alpha = statistics.mean(df.iloc[12:18, 13])
mean_COH_pcn_gamma = statistics.mean(df.iloc[18:24, 13])
mean_COH_pcn = [mean_COH_pcn_delta, mean_COH_pcn_theta, mean_COH_pcn_alpha, mean_COH_pcn_gamma]

mean_SECOH_pcn_delta = scipy.stats.sem(df.iloc[0:6, 13])
mean_SECOH_pcn_theta = scipy.stats.sem(df.iloc[6:12, 13])
mean_SECOH_pcn_alpha = scipy.stats.sem(df.iloc[12:18, 13])
mean_SECOH_pcn_gamma = scipy.stats.sem(df.iloc[18:24, 13])
mean_SECOH_pcn = [mean_SECOH_pcn_delta, mean_SECOH_pcn_theta, mean_SECOH_pcn_alpha, mean_SECOH_pcn_gamma]

mean_COH_tcn_delta = statistics.mean(df.iloc[24:30, 13])
mean_COH_tcn_theta = statistics.mean(df.iloc[30:36, 13])
mean_COH_tcn_alpha = statistics.mean(df.iloc[36:42, 13])
mean_COH_tcn_gamma = statistics.mean(df.iloc[42:48, 13])
mean_COH_tcn = [mean_COH_tcn_delta, mean_COH_tcn_theta, mean_COH_tcn_alpha, mean_COH_tcn_gamma]

mean_SECOH_tcn_delta = scipy.stats.sem(df.iloc[24:30, 13])
mean_SECOH_tcn_theta = scipy.stats.sem(df.iloc[30:36, 13])
mean_SECOH_tcn_alpha = scipy.stats.sem(df.iloc[36:42, 13])
mean_SECOH_tcn_gamma = scipy.stats.sem(df.iloc[42:48, 13])
mean_SECOH_tcn = [mean_SECOH_tcn_delta, mean_SECOH_tcn_theta, mean_SECOH_tcn_alpha, mean_SECOH_tcn_gamma]

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_iCOH_pcn_delta = statistics.mean(df.iloc[0:6, 15])
mean_iCOH_pcn_theta = statistics.mean(df.iloc[6:12, 15])
mean_iCOH_pcn_alpha = statistics.mean(df.iloc[12:18, 15])
mean_iCOH_pcn_gamma = statistics.mean(df.iloc[18:24, 15])
mean_iCOH_pcn = [mean_iCOH_pcn_delta, mean_iCOH_pcn_theta, mean_iCOH_pcn_alpha, mean_iCOH_pcn_gamma]

mean_SEiCOH_pcn_delta = scipy.stats.sem(df.iloc[0:6, 15])
mean_SEiCOH_pcn_theta = scipy.stats.sem(df.iloc[6:12, 15])
mean_SEiCOH_pcn_alpha = scipy.stats.sem(df.iloc[12:18, 15])
mean_SEiCOH_pcn_gamma = scipy.stats.sem(df.iloc[18:24, 15])
mean_SEiCOH_pcn = [mean_SEiCOH_pcn_delta, mean_SEiCOH_pcn_theta, mean_SEiCOH_pcn_alpha, mean_SEiCOH_pcn_gamma]

mean_iCOH_tcn_delta = statistics.mean(df.iloc[24:30, 15])
mean_iCOH_tcn_theta = statistics.mean(df.iloc[30:36, 15])
mean_iCOH_tcn_alpha = statistics.mean(df.iloc[36:42, 15])
mean_iCOH_tcn_gamma = statistics.mean(df.iloc[42:48, 15])
mean_iCOH_tcn = [mean_iCOH_tcn_delta, mean_iCOH_tcn_theta, mean_iCOH_tcn_alpha, mean_iCOH_tcn_gamma]

mean_SEiCOH_tcn_delta = scipy.stats.sem(df.iloc[24:30, 15])
mean_SEiCOH_tcn_theta = scipy.stats.sem(df.iloc[30:36, 15])
mean_SEiCOH_tcn_alpha = scipy.stats.sem(df.iloc[36:42, 15])
mean_SEiCOH_tcn_gamma = scipy.stats.sem(df.iloc[42:48, 15])
mean_SEiCOH_tcn = [mean_SEiCOH_tcn_delta, mean_SEiCOH_tcn_theta, mean_SEiCOH_tcn_alpha, mean_SEiCOH_tcn_gamma]

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_COH_phc_delta = statistics.mean(df.iloc[48:53, 13])
mean_COH_phc_theta = statistics.mean(df.iloc[53:58, 13])
mean_COH_phc_alpha = statistics.mean(df.iloc[58:63, 13])
mean_COH_phc_gamma = statistics.mean(df.iloc[63:68, 13])
mean_COH_phc = [mean_COH_phc_delta, mean_COH_phc_theta, mean_COH_phc_alpha, mean_COH_phc_gamma]

mean_SECOH_phc_delta = scipy.stats.sem(df.iloc[48:53, 13])
mean_SECOH_phc_theta = scipy.stats.sem(df.iloc[53:58, 13])
mean_SECOH_phc_alpha = scipy.stats.sem(df.iloc[58:63, 13])
mean_SECOH_phc_gamma = scipy.stats.sem(df.iloc[63:68, 13])
mean_SECOH_phc = [mean_SECOH_phc_delta, mean_SECOH_phc_theta, mean_SECOH_phc_alpha, mean_SECOH_phc_gamma]

mean_COH_thc_delta = statistics.mean(df.iloc[68:74, 13])
mean_COH_thc_theta = statistics.mean(df.iloc[74:80, 13])
mean_COH_thc_alpha = statistics.mean(df.iloc[80:86, 13])
mean_COH_thc_gamma = statistics.mean(df.iloc[86:92, 13])
mean_COH_thc = [mean_COH_thc_delta, mean_COH_thc_theta, mean_COH_thc_alpha, mean_COH_thc_gamma]

mean_SECOH_thc_delta = scipy.stats.sem(df.iloc[68:74, 13])
mean_SECOH_thc_theta = scipy.stats.sem(df.iloc[74:80, 13])
mean_SECOH_thc_alpha = scipy.stats.sem(df.iloc[80:86, 13])
mean_SECOH_thc_gamma = scipy.stats.sem(df.iloc[86:92, 13])
mean_SECOH_thc = [mean_SECOH_thc_delta, mean_SECOH_thc_theta, mean_SECOH_thc_alpha, mean_SECOH_thc_gamma]

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_iCOH_phc_delta = statistics.mean(df.iloc[48:53, 15])
mean_iCOH_phc_theta = statistics.mean(df.iloc[53:58, 15])
mean_iCOH_phc_alpha = statistics.mean(df.iloc[58:63, 15])
mean_iCOH_phc_gamma = statistics.mean(df.iloc[63:68, 15])
mean_iCOH_phc = [mean_iCOH_phc_delta, mean_iCOH_phc_theta, mean_iCOH_phc_alpha, mean_iCOH_phc_gamma]

mean_SEiCOH_phc_delta = scipy.stats.sem(df.iloc[48:53, 15])
mean_SEiCOH_phc_theta = scipy.stats.sem(df.iloc[53:58, 15])
mean_SEiCOH_phc_alpha = scipy.stats.sem(df.iloc[58:63, 15])
mean_SEiCOH_phc_gamma = scipy.stats.sem(df.iloc[63:68, 15])
mean_SEiCOH_phc = [mean_SEiCOH_phc_delta, mean_SEiCOH_phc_theta, mean_SEiCOH_phc_alpha, mean_SEiCOH_phc_gamma]

mean_iCOH_thc_delta = statistics.mean(df.iloc[68:74, 15])
mean_iCOH_thc_theta = statistics.mean(df.iloc[74:80, 15])
mean_iCOH_thc_alpha = statistics.mean(df.iloc[80:86, 15])
mean_iCOH_thc_gamma = statistics.mean(df.iloc[86:92, 15])
mean_iCOH_thc = [mean_iCOH_thc_delta, mean_iCOH_thc_theta, mean_iCOH_thc_alpha, mean_iCOH_thc_gamma]

mean_SEiCOH_thc_delta = scipy.stats.sem(df.iloc[68:74, 15])
mean_SEiCOH_thc_theta = scipy.stats.sem(df.iloc[74:80, 15])
mean_SEiCOH_thc_alpha = scipy.stats.sem(df.iloc[80:86, 15])
mean_SEiCOH_thc_gamma = scipy.stats.sem(df.iloc[86:92, 15])
mean_SEiCOH_thc = [mean_SEiCOH_thc_delta, mean_SEiCOH_thc_theta, mean_SEiCOH_thc_alpha, mean_SEiCOH_thc_gamma]

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_COH_pod_delta = statistics.mean(df.iloc[92:98, 13])
mean_COH_pod_theta = statistics.mean(df.iloc[98:104, 13])
mean_COH_pod_alpha = statistics.mean(df.iloc[104:110, 13])
mean_COH_pod_gamma = statistics.mean(df.iloc[110:116, 13])
mean_COH_pod = [mean_COH_pod_delta, mean_COH_pod_theta, mean_COH_pod_alpha, mean_COH_pod_gamma]

mean_SECOH_pod_delta = scipy.stats.sem(df.iloc[92:98, 13])
mean_SECOH_pod_theta = scipy.stats.sem(df.iloc[98:104, 13])
mean_SECOH_pod_alpha = scipy.stats.sem(df.iloc[104:110, 13])
mean_SECOH_pod_gamma = scipy.stats.sem(df.iloc[110:116, 13])
mean_SECOH_pod = [mean_SECOH_pod_delta, mean_SECOH_pod_theta, mean_SECOH_pod_alpha, mean_SECOH_pod_gamma]

mean_COH_tod_delta = statistics.mean(df.iloc[116:122, 13])
mean_COH_tod_theta = statistics.mean(df.iloc[122:128, 13])
mean_COH_tod_alpha = statistics.mean(df.iloc[128:134, 13])
mean_COH_tod_gamma = statistics.mean(df.iloc[134:140, 13])
mean_COH_tod = [mean_COH_tod_delta, mean_COH_tod_theta, mean_COH_tod_alpha, mean_COH_tod_gamma]

mean_SECOH_tod_delta = scipy.stats.sem(df.iloc[116:122, 13])
mean_SECOH_tod_theta = scipy.stats.sem(df.iloc[122:128, 13])
mean_SECOH_tod_alpha = scipy.stats.sem(df.iloc[128:134, 13])
mean_SECOH_tod_gamma = scipy.stats.sem(df.iloc[134:140, 13])
mean_SECOH_tod = [mean_SECOH_tod_delta, mean_SECOH_tod_theta, mean_SECOH_tod_alpha, mean_SECOH_tod_gamma]

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_iCOH_pod_delta = statistics.mean(df.iloc[92:98, 15])
mean_iCOH_pod_theta = statistics.mean(df.iloc[98:104, 15])
mean_iCOH_pod_alpha = statistics.mean(df.iloc[104:110, 15])
mean_iCOH_pod_gamma = statistics.mean(df.iloc[110:116, 15])
mean_iCOH_pod = [mean_iCOH_pod_delta, mean_iCOH_pod_theta, mean_iCOH_pod_alpha, mean_iCOH_pod_gamma]

mean_SEiCOH_pod_delta = scipy.stats.sem(df.iloc[92:98, 15])
mean_SEiCOH_pod_theta = scipy.stats.sem(df.iloc[98:104, 15])
mean_SEiCOH_pod_alpha = scipy.stats.sem(df.iloc[104:110, 15])
mean_SEiCOH_pod_gamma = scipy.stats.sem(df.iloc[110:116, 15])
mean_SEiCOH_pod = [mean_SEiCOH_pod_delta, mean_SEiCOH_pod_theta, mean_SEiCOH_pod_alpha, mean_SEiCOH_pod_gamma]

mean_iCOH_tod_delta = statistics.mean(df.iloc[116:122, 15])
mean_iCOH_tod_theta = statistics.mean(df.iloc[122:128, 15])
mean_iCOH_tod_alpha = statistics.mean(df.iloc[128:134, 15])
mean_iCOH_tod_gamma = statistics.mean(df.iloc[134:140, 15])
mean_iCOH_tod = [mean_iCOH_tod_delta, mean_iCOH_tod_theta, mean_iCOH_tod_alpha, mean_iCOH_tod_gamma]

mean_SEiCOH_tod_delta = scipy.stats.sem(df.iloc[116:122, 15])
mean_SEiCOH_tod_theta = scipy.stats.sem(df.iloc[122:128, 15])
mean_SEiCOH_tod_alpha = scipy.stats.sem(df.iloc[128:134, 15])
mean_SEiCOH_tod_gamma = scipy.stats.sem(df.iloc[134:140, 15])
mean_SEiCOH_tod = [mean_SEiCOH_tod_delta, mean_SEiCOH_tod_theta, mean_SEiCOH_tod_alpha, mean_SEiCOH_tod_gamma]

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_COH_por_delta = statistics.mean(df.iloc[140:146, 13])
mean_COH_por_theta = statistics.mean(df.iloc[146:152, 13])
mean_COH_por_alpha = statistics.mean(df.iloc[152:158, 13])
mean_COH_por_gamma = statistics.mean(df.iloc[158:164, 13])
mean_COH_por = [mean_COH_por_delta, mean_COH_por_theta, mean_COH_por_alpha, mean_COH_por_gamma]

mean_SECOH_por_delta = scipy.stats.sem(df.iloc[140:146, 13])
mean_SECOH_por_theta = scipy.stats.sem(df.iloc[146:152, 13])
mean_SECOH_por_alpha = scipy.stats.sem(df.iloc[152:158, 13])
mean_SECOH_por_gamma = scipy.stats.sem(df.iloc[158:164, 13])
mean_SECOH_por = [mean_SECOH_por_delta, mean_SECOH_por_theta, mean_SECOH_por_alpha, mean_SECOH_por_gamma]

mean_COH_tor_delta = statistics.mean(df.iloc[164:170, 13])
mean_COH_tor_theta = statistics.mean(df.iloc[170:176, 13])
mean_COH_tor_alpha = statistics.mean(df.iloc[176:182, 13])
mean_COH_tor_gamma = statistics.mean(df.iloc[182:188, 13])
mean_COH_tor = [mean_COH_tor_delta, mean_COH_tor_theta, mean_COH_tor_alpha, mean_COH_tor_gamma]

mean_SECOH_tor_delta = scipy.stats.sem(df.iloc[164:170, 13])
mean_SECOH_tor_theta = scipy.stats.sem(df.iloc[170:176, 13])
mean_SECOH_tor_alpha = scipy.stats.sem(df.iloc[176:182, 13])
mean_SECOH_tor_gamma = scipy.stats.sem(df.iloc[182:188, 13])
mean_SECOH_tor = [mean_SECOH_tor_delta, mean_SECOH_tor_theta, mean_SECOH_tor_alpha, mean_SECOH_tor_gamma]

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_iCOH_por_delta = statistics.mean(df.iloc[140:146, 15])
mean_iCOH_por_theta = statistics.mean(df.iloc[146:152, 15])
mean_iCOH_por_alpha = statistics.mean(df.iloc[152:158, 15])
mean_iCOH_por_gamma = statistics.mean(df.iloc[158:164, 15])
mean_iCOH_por = [mean_iCOH_por_delta, mean_iCOH_por_theta, mean_iCOH_por_alpha, mean_iCOH_por_gamma]

mean_SEiCOH_por_delta = scipy.stats.sem(df.iloc[140:146, 15])
mean_SEiCOH_por_theta = scipy.stats.sem(df.iloc[146:152, 15])
mean_SEiCOH_por_alpha = scipy.stats.sem(df.iloc[152:158, 15])
mean_SEiCOH_por_gamma = scipy.stats.sem(df.iloc[158:164, 15])
mean_SEiCOH_por = [mean_SEiCOH_por_delta, mean_SEiCOH_por_theta, mean_SEiCOH_por_alpha, mean_SEiCOH_por_gamma]

mean_iCOH_tor_delta = statistics.mean(df.iloc[164:170, 15])
mean_iCOH_tor_theta = statistics.mean(df.iloc[170:176, 15])
mean_iCOH_tor_alpha = statistics.mean(df.iloc[176:182, 15])
mean_iCOH_tor_gamma = statistics.mean(df.iloc[182:188, 15])
mean_iCOH_tor = [mean_iCOH_tor_delta, mean_iCOH_tor_theta, mean_iCOH_tor_alpha, mean_iCOH_tor_gamma]

mean_SEiCOH_tor_delta = scipy.stats.sem(df.iloc[164:170, 15])
mean_SEiCOH_tor_theta = scipy.stats.sem(df.iloc[170:176, 15])
mean_SEiCOH_tor_alpha = scipy.stats.sem(df.iloc[176:182, 15])
mean_SEiCOH_tor_gamma = scipy.stats.sem(df.iloc[182:188, 15])
mean_SEiCOH_tor = [mean_SEiCOH_tor_delta, mean_SEiCOH_tor_theta, mean_SEiCOH_tor_alpha, mean_SEiCOH_tor_gamma]

# %%
fig, axes = plt.subplots(nrows=7, ncols=2, figsize=(15, 20), constrained_layout=True)
axes[0,0].scatter(frequency_pcn, COH_pcn, label='phasic CN')
axes[0,0].scatter(frequency_phc, COH_phc, label='phasic HC')
axes[0,0].scatter(frequency_pod, COH_pod, label='phasic OD')
axes[0,0].scatter(frequency_por, COH_por, label='phasic OR')
axes[0,0].scatter(frequency_tcn, COH_tcn, label='tonic CN')
axes[0,0].scatter(frequency_thc, COH_thc, label='tonic HC')
axes[0,0].scatter(frequency_tod, COH_tod, label='tonic OD')
axes[0,0].scatter(frequency_tor, COH_tor, label='tonic OR')
axes[0,0].legend()
axes[0,0].set_xlabel('frequency bin')
axes[0,0].set_ylabel('COH')

axes[0,1].scatter(frequency_pcn, iCOH_pcn, label='phasic CN')
axes[0,1].scatter(frequency_phc, iCOH_phc, label='phasic HC')
axes[0,1].scatter(frequency_pod, iCOH_pod, label='phasic OD')
axes[0,1].scatter(frequency_por, iCOH_por, label='phasic OR')
axes[0,1].scatter(frequency_tcn, iCOH_tcn, label='tonic CN')
axes[0,1].scatter(frequency_thc, iCOH_thc, label='tonic HC')
axes[0,1].scatter(frequency_tod, iCOH_tod, label='tonic OD')
axes[0,1].scatter(frequency_tor, iCOH_tor, label='tonic OR')
axes[0,1].legend()
axes[0,1].set_xlabel('frequency bin')
axes[0,1].set_ylabel('iCOH')

axes[1,0].scatter(frequency_pcn, COH_pcn, label='phasic CN')
axes[1,0].errorbar(frequencies, mean_COH_pcn, mean_SECOH_pcn, fmt="v", color = 'black', label='mean')
axes[1,0].scatter(frequency_tcn, COH_tcn, label='tonic CN')
axes[1,0].errorbar(frequencies, mean_COH_tcn, mean_SECOH_tcn, fmt="v", color = 'black')
axes[1,0].legend()
axes[1,0].set_xlabel('frequency bin')
axes[1,0].set_ylabel('COH')

axes[1,1].scatter(frequency_pcn, iCOH_pcn, label='phasic CN')
axes[1,1].errorbar(frequencies, mean_iCOH_pcn, mean_SEiCOH_pcn, fmt="v", color = 'black', label='mean')
axes[1,1].scatter(frequency_tcn, iCOH_tcn, label='tonic CN')
axes[1,1].errorbar(frequencies, mean_iCOH_tcn, mean_SEiCOH_tcn, fmt="v", color = 'black')
axes[1,1].legend()
axes[1,1].set_xlabel('frequency bin')
axes[1,1].set_ylabel('iCOH')

axes[2,0].scatter(frequency_phc, COH_phc, label='phasic HC')
axes[2,0].errorbar(frequencies, mean_COH_phc, mean_SECOH_phc, fmt="v", color = 'black', label='mean')
axes[2,0].scatter(frequency_thc, COH_thc, label='tonic HC')
axes[2,0].errorbar(frequencies, mean_COH_thc, mean_SECOH_thc, fmt="v", color = 'black')
axes[2,0].legend()
axes[2,0].set_xlabel('frequency bin')
axes[2,0].set_ylabel('COH')

axes[2,1].scatter(frequency_phc, iCOH_phc, label='phasic HC')
axes[2,1].errorbar(frequencies, mean_iCOH_phc, mean_SEiCOH_phc, fmt="v", color = 'black', label='mean')
axes[2,1].scatter(frequency_thc, iCOH_thc, label='tonic HC')
axes[2,1].errorbar(frequencies, mean_iCOH_thc, mean_SEiCOH_thc, fmt="v", color = 'black')
axes[2,1].legend()
axes[2,1].set_xlabel('frequency bin')
axes[2,1].set_ylabel('iCOH')

axes[3,0].scatter(frequency_pod, COH_pod, label='phasic OD')
axes[3,0].errorbar(frequencies, mean_COH_pod, mean_SECOH_pod, fmt="v", color = 'black')
axes[3,0].scatter(frequency_tod, COH_tod, label='tonic OD')
axes[3,0].errorbar(frequencies, mean_COH_tod, mean_SECOH_tod, fmt="v", color = 'black')
axes[3,0].legend()
axes[3,0].set_xlabel('frequency bin')
axes[3,0].set_ylabel('COH')

axes[3,1].scatter(frequency_pod, iCOH_pod, label='phasic OD')
axes[3,1].errorbar(frequencies, mean_iCOH_pod, mean_SEiCOH_pod, fmt="v", color = 'black')
axes[3,1].scatter(frequency_tod, iCOH_tod, label='tonic OD')
axes[3,1].errorbar(frequencies, mean_iCOH_tod, mean_SEiCOH_tod, fmt="v", color = 'black')
axes[3,1].legend()
axes[3,1].set_xlabel('frequency bin')
axes[3,1].set_ylabel('iCOH')

axes[4,0].scatter(frequency_por, COH_por, label='phasic OR')
axes[4,0].errorbar(frequencies, mean_COH_por, mean_SECOH_por, fmt="v", color = 'black')
axes[4,0].scatter(frequency_tor, COH_tor, label='tonic OR')
axes[4,0].errorbar(frequencies, mean_COH_tor, mean_SECOH_tor, fmt="v", color = 'black')
axes[4,0].legend()
axes[4,0].set_xlabel('frequency bin')
axes[4,0].set_ylabel('COH')

axes[4,1].scatter(frequency_por, iCOH_por, label='phasic OR')
axes[4,1].errorbar(frequencies, mean_iCOH_por, mean_SEiCOH_por, fmt="v", color = 'black')
axes[4,1].scatter(frequency_tor, iCOH_tor, label='tonic OR')
axes[4,1].errorbar(frequencies, mean_iCOH_tor, mean_SEiCOH_tor, fmt="v", color = 'black')
axes[4,1].legend()
axes[4,1].set_xlabel('frequency bin')
axes[4,1].set_ylabel('iCOH')

axes[5,0].errorbar(frequencies, mean_COH_pcn, mean_SECOH_pcn, fmt="v", label ='CN')
axes[6,0].errorbar(frequencies, mean_COH_tcn, mean_SECOH_tcn, fmt="v", label = 'CN')
axes[5,0].errorbar(frequencies, mean_COH_phc, mean_SECOH_phc, fmt="v", label = 'HC')
axes[6,0].errorbar(frequencies, mean_COH_thc, mean_SECOH_thc, fmt="v", label = 'HC')
axes[5,0].errorbar(frequencies, mean_COH_pod, mean_SECOH_pod, fmt="v", label = 'OD')
axes[6,0].errorbar(frequencies, mean_COH_tod, mean_SECOH_tod, fmt="v", label = 'OD')
axes[5,0].errorbar(frequencies, mean_COH_por, mean_SECOH_por, fmt="v", label = 'OR', color ='purple')
axes[6,0].errorbar(frequencies, mean_COH_tor, mean_SECOH_tor, fmt="v", label = 'OR', color ='purple')
axes[5,0].set_xlabel('frequency bin')
axes[5,0].set_ylabel('phasic COH')
axes[5,0].legend()
axes[6,0].set_xlabel('frequency bin')
axes[6,0].set_ylabel('tonic COH')
axes[6,0].legend()

axes[5,1].errorbar(frequencies, mean_iCOH_pcn, mean_SEiCOH_pcn, fmt="v", label = 'CN')
axes[6,1].errorbar(frequencies, mean_iCOH_tcn, mean_SEiCOH_tcn, fmt="v", label = 'CN')
axes[5,1].errorbar(frequencies, mean_iCOH_phc, mean_SEiCOH_phc, fmt="v", label = 'HC')
axes[6,1].errorbar(frequencies, mean_iCOH_thc, mean_SEiCOH_thc, fmt="v", label = 'HC')
axes[5,1].errorbar(frequencies, mean_iCOH_pod, mean_SEiCOH_pod, fmt="v", label = 'OD')
axes[6,1].errorbar(frequencies, mean_iCOH_tod, mean_SEiCOH_tod, fmt="v", label = 'OD')
axes[5,1].errorbar(frequencies, mean_iCOH_por, mean_SEiCOH_por, fmt="v", label = 'OR', color ='purple')
axes[6,1].errorbar(frequencies, mean_iCOH_tor, mean_SEiCOH_tor, fmt="v", label = 'OR', color ='purple')
axes[5,1].set_xlabel('frequency bin')
axes[5,1].set_ylabel('phasic iCOH')
axes[5,1].legend()
axes[6,1].set_xlabel('frequency bin')
axes[6,1].set_ylabel('tonic iCOH')
axes[6,1].legend()

# %%
cats = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']

# Bar width and x locations
w, x = 0.2, np.arange(len(cats))

fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(15, 6), constrained_layout=True)
ax[0,0].bar(x - 1.5*w, mean_COH_pcn, width=w, label='CN')
ax[0,0].errorbar(x - 1.5*w, mean_COH_pcn, mean_SECOH_pcn, fmt="v", color = 'black')
ax[0,0].bar(x - 0.5*w, mean_COH_phc, width=w, label='HC')
ax[0,0].errorbar(x - w/2, mean_COH_phc, mean_SECOH_phc, fmt="v", color = 'black')
ax[0,0].bar(x + w/2, mean_COH_pod, width=w, label='OD')
ax[0,0].errorbar(x + w/2, mean_COH_pod, mean_SECOH_pod, fmt="v", color = 'black')
ax[0,0].bar(x + 1.5*w, mean_COH_por, width=w, label='OR', color = 'purple')
ax[0,0].errorbar(x + 1.5*w, mean_COH_por, mean_SECOH_por, fmt="v", color = 'black')

ax[0,0].set_xticks(x)
ax[0,0].set_xticklabels(cats)
ax[0,0].set_ylabel('phasic COH')
ax[0,0].legend()

ax[0,1].bar(x - 1.5*w, mean_iCOH_pcn, width=w, label='CN')
ax[0,1].errorbar(x - 1.5*w, mean_iCOH_pcn, mean_SEiCOH_pcn, fmt="v", color = 'black')
ax[0,1].bar(x - 0.5*w, mean_iCOH_phc, width=w, label='HC')
ax[0,1].errorbar(x - w/2, mean_iCOH_phc, mean_SEiCOH_phc, fmt="v", color = 'black')
ax[0,1].bar(x + w/2, mean_iCOH_pod, width=w, label='OD')
ax[0,1].errorbar(x + w/2, mean_iCOH_pod, mean_SEiCOH_pod, fmt="v", color = 'black')
ax[0,1].bar(x + 1.5*w, mean_iCOH_por, width=w, label='OR', color = 'purple')
ax[0,1].errorbar(x + 1.5*w, mean_iCOH_por, mean_SEiCOH_por, fmt="v", color = 'black')

ax[0,1].set_xticks(x)
ax[0,1].set_xticklabels(cats)
ax[0,1].set_ylabel('phasic iCOH')
ax[0,1].legend()

ax[1,0].bar(x - 1.5*w, mean_COH_tcn, width=w, label='CN')
ax[1,0].errorbar(x - 1.5*w, mean_COH_tcn, mean_SECOH_tcn, fmt="v", color = 'black')
ax[1,0].bar(x - 0.5*w, mean_COH_thc, width=w, label='HC')
ax[1,0].errorbar(x - w/2, mean_COH_thc, mean_SECOH_thc, fmt="v", color = 'black')
ax[1,0].bar(x + w/2, mean_COH_tod, width=w, label='OD')
ax[1,0].errorbar(x + w/2, mean_COH_tod, mean_SECOH_tod, fmt="v", color = 'black')
ax[1,0].bar(x + 1.5*w, mean_COH_tor, width=w, label='OR', color = 'purple')
ax[1,0].errorbar(x + 1.5*w, mean_COH_tor, mean_SECOH_tor, fmt="v", color = 'black')

ax[1,0].set_xticks(x)
ax[1,0].set_xticklabels(cats)
ax[1,0].set_ylabel('tonic COH')
ax[1,0].legend()

ax[1,1].bar(x - 1.5*w, mean_iCOH_tcn, width=w, label='CN')
ax[1,1].errorbar(x - 1.5*w, mean_iCOH_tcn, mean_SEiCOH_tcn, fmt="v", color = 'black')
ax[1,1].bar(x - 0.5*w, mean_iCOH_thc, width=w, label='HC')
ax[1,1].errorbar(x - w/2, mean_iCOH_thc, mean_SEiCOH_thc, fmt="v", color = 'black')
ax[1,1].bar(x + w/2, mean_iCOH_tod, width=w, label='OD')
ax[1,1].errorbar(x + w/2, mean_iCOH_tod, mean_SEiCOH_tod, fmt="v", color = 'black')
ax[1,1].bar(x + 1.5*w, mean_iCOH_tor, width=w, label='OR', color = 'purple')
ax[1,1].errorbar(x + 1.5*w, mean_iCOH_tor, mean_SEiCOH_tor, fmt="v", color = 'black')

ax[1,1].set_xticks(x)
ax[1,1].set_xticklabels(cats)
ax[1,1].set_ylabel('tonic iCOH')
ax[1,1].legend()

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_PLI_pcn_delta = statistics.mean(df.iloc[0:6, 17])
mean_PLI_pcn_theta = statistics.mean(df.iloc[6:12, 17])
mean_PLI_pcn_alpha = statistics.mean(df.iloc[12:18, 17])
mean_PLI_pcn_gamma = statistics.mean(df.iloc[18:24, 17])
mean_PLI_pcn = [mean_PLI_pcn_delta, mean_PLI_pcn_theta, mean_PLI_pcn_alpha, mean_PLI_pcn_gamma]

mean_SEPLI_pcn_delta = scipy.stats.sem(df.iloc[0:6, 17])
mean_SEPLI_pcn_theta = scipy.stats.sem(df.iloc[6:12, 17])
mean_SEPLI_pcn_alpha = scipy.stats.sem(df.iloc[12:18, 17])
mean_SEPLI_pcn_gamma = scipy.stats.sem(df.iloc[18:24, 17])
mean_SEPLI_pcn = [mean_SEPLI_pcn_delta, mean_SEPLI_pcn_theta, mean_SEPLI_pcn_alpha, mean_SEPLI_pcn_gamma]

mean_PLI_tcn_delta = statistics.mean(df.iloc[24:30, 17])
mean_PLI_tcn_theta = statistics.mean(df.iloc[30:36, 17])
mean_PLI_tcn_alpha = statistics.mean(df.iloc[36:42, 17])
mean_PLI_tcn_gamma = statistics.mean(df.iloc[42:48, 17])
mean_PLI_tcn = [mean_PLI_tcn_delta, mean_PLI_tcn_theta, mean_PLI_tcn_alpha, mean_PLI_tcn_gamma]

mean_SEPLI_tcn_delta = scipy.stats.sem(df.iloc[24:30, 17])
mean_SEPLI_tcn_theta = scipy.stats.sem(df.iloc[30:36, 17])
mean_SEPLI_tcn_alpha = scipy.stats.sem(df.iloc[36:42, 17])
mean_SEPLI_tcn_gamma = scipy.stats.sem(df.iloc[42:48, 17])
mean_SEPLI_tcn = [mean_SEPLI_tcn_delta, mean_SEPLI_tcn_theta, mean_SEPLI_tcn_alpha, mean_SEPLI_tcn_gamma]

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_wPLI_pcn_delta = statistics.mean(df.iloc[0:6, 19])
mean_wPLI_pcn_theta = statistics.mean(df.iloc[6:12, 19])
mean_wPLI_pcn_alpha = statistics.mean(df.iloc[12:18, 19])
mean_wPLI_pcn_gamma = statistics.mean(df.iloc[18:24, 19])
mean_wPLI_pcn = [mean_wPLI_pcn_delta, mean_wPLI_pcn_theta, mean_wPLI_pcn_alpha, mean_wPLI_pcn_gamma]

mean_SEwPLI_pcn_delta = scipy.stats.sem(df.iloc[0:6, 19])
mean_SEwPLI_pcn_theta = scipy.stats.sem(df.iloc[6:12, 19])
mean_SEwPLI_pcn_alpha = scipy.stats.sem(df.iloc[12:18, 19])
mean_SEwPLI_pcn_gamma = scipy.stats.sem(df.iloc[18:24, 19])
mean_SEwPLI_pcn = [mean_SEwPLI_pcn_delta, mean_SEwPLI_pcn_theta, mean_SEwPLI_pcn_alpha, mean_SEwPLI_pcn_gamma]

mean_wPLI_tcn_delta = statistics.mean(df.iloc[24:30, 19])
mean_wPLI_tcn_theta = statistics.mean(df.iloc[30:36, 19])
mean_wPLI_tcn_alpha = statistics.mean(df.iloc[36:42, 19])
mean_wPLI_tcn_gamma = statistics.mean(df.iloc[42:48, 19])
mean_wPLI_tcn = [mean_wPLI_tcn_delta, mean_wPLI_tcn_theta, mean_wPLI_tcn_alpha, mean_wPLI_tcn_gamma]

mean_SEwPLI_tcn_delta = scipy.stats.sem(df.iloc[24:30, 19])
mean_SEwPLI_tcn_theta = scipy.stats.sem(df.iloc[30:36, 19])
mean_SEwPLI_tcn_alpha = scipy.stats.sem(df.iloc[36:42, 19])
mean_SEwPLI_tcn_gamma = scipy.stats.sem(df.iloc[42:48, 19])
mean_SEwPLI_tcn = [mean_SEwPLI_tcn_delta, mean_SEwPLI_tcn_theta, mean_SEwPLI_tcn_alpha, mean_SEwPLI_tcn_gamma]

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_PLI_phc_delta = statistics.mean(df.iloc[48:53, 17])
mean_PLI_phc_theta = statistics.mean(df.iloc[53:58, 17])
mean_PLI_phc_alpha = statistics.mean(df.iloc[58:63, 17])
mean_PLI_phc_gamma = statistics.mean(df.iloc[63:68, 17])
mean_PLI_phc = [mean_PLI_phc_delta, mean_PLI_phc_theta, mean_PLI_phc_alpha, mean_PLI_phc_gamma]

mean_SEPLI_phc_delta = scipy.stats.sem(df.iloc[48:53, 17])
mean_SEPLI_phc_theta = scipy.stats.sem(df.iloc[53:58, 17])
mean_SEPLI_phc_alpha = scipy.stats.sem(df.iloc[58:63, 17])
mean_SEPLI_phc_gamma = scipy.stats.sem(df.iloc[63:68, 17])
mean_SEPLI_phc = [mean_SEPLI_phc_delta, mean_SEPLI_phc_theta, mean_SEPLI_phc_alpha, mean_SEPLI_phc_gamma]

mean_PLI_thc_delta = statistics.mean(df.iloc[68:74, 17])
mean_PLI_thc_theta = statistics.mean(df.iloc[74:80, 17])
mean_PLI_thc_alpha = statistics.mean(df.iloc[80:86, 17])
mean_PLI_thc_gamma = statistics.mean(df.iloc[86:92, 17])
mean_PLI_thc = [mean_PLI_thc_delta, mean_PLI_thc_theta, mean_PLI_thc_alpha, mean_PLI_thc_gamma]

mean_SEPLI_thc_delta = scipy.stats.sem(df.iloc[68:74, 17])
mean_SEPLI_thc_theta = scipy.stats.sem(df.iloc[74:80, 17])
mean_SEPLI_thc_alpha = scipy.stats.sem(df.iloc[80:86, 17])
mean_SEPLI_thc_gamma = scipy.stats.sem(df.iloc[86:92, 17])
mean_SEPLI_thc = [mean_SEPLI_thc_delta, mean_SEPLI_thc_theta, mean_SEPLI_thc_alpha, mean_SEPLI_thc_gamma]

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_wPLI_phc_delta = statistics.mean(df.iloc[48:53, 19])
mean_wPLI_phc_theta = statistics.mean(df.iloc[53:58, 19])
mean_wPLI_phc_alpha = statistics.mean(df.iloc[58:63, 19])
mean_wPLI_phc_gamma = statistics.mean(df.iloc[63:68, 19])
mean_wPLI_phc = [mean_wPLI_phc_delta, mean_wPLI_phc_theta, mean_wPLI_phc_alpha, mean_wPLI_phc_gamma]

mean_SEwPLI_phc_delta = scipy.stats.sem(df.iloc[48:53, 19])
mean_SEwPLI_phc_theta = scipy.stats.sem(df.iloc[53:58, 19])
mean_SEwPLI_phc_alpha = scipy.stats.sem(df.iloc[58:63, 19])
mean_SEwPLI_phc_gamma = scipy.stats.sem(df.iloc[63:68, 19])
mean_SEwPLI_phc = [mean_SEwPLI_phc_delta, mean_SEwPLI_phc_theta, mean_SEwPLI_phc_alpha, mean_SEwPLI_phc_gamma]

mean_wPLI_thc_delta = statistics.mean(df.iloc[68:74, 19])
mean_wPLI_thc_theta = statistics.mean(df.iloc[74:80, 19])
mean_wPLI_thc_alpha = statistics.mean(df.iloc[80:86, 19])
mean_wPLI_thc_gamma = statistics.mean(df.iloc[86:92, 19])
mean_wPLI_thc = [mean_wPLI_thc_delta, mean_wPLI_thc_theta, mean_wPLI_thc_alpha, mean_wPLI_thc_gamma]

mean_SEwPLI_thc_delta = scipy.stats.sem(df.iloc[68:74, 19])
mean_SEwPLI_thc_theta = scipy.stats.sem(df.iloc[74:80, 19])
mean_SEwPLI_thc_alpha = scipy.stats.sem(df.iloc[80:86, 19])
mean_SEwPLI_thc_gamma = scipy.stats.sem(df.iloc[86:92, 19])
mean_SEwPLI_thc = [mean_SEwPLI_thc_delta, mean_SEwPLI_thc_theta, mean_SEwPLI_thc_alpha, mean_SEwPLI_thc_gamma]

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_PLI_pod_delta = statistics.mean(df.iloc[92:98, 17])
mean_PLI_pod_theta = statistics.mean(df.iloc[98:104, 17])
mean_PLI_pod_alpha = statistics.mean(df.iloc[104:110, 17])
mean_PLI_pod_gamma = statistics.mean(df.iloc[110:116, 17])
mean_PLI_pod = [mean_PLI_pod_delta, mean_PLI_pod_theta, mean_PLI_pod_alpha, mean_PLI_pod_gamma]

mean_SEPLI_pod_delta = scipy.stats.sem(df.iloc[92:98, 17])
mean_SEPLI_pod_theta = scipy.stats.sem(df.iloc[98:104, 17])
mean_SEPLI_pod_alpha = scipy.stats.sem(df.iloc[104:110, 17])
mean_SEPLI_pod_gamma = scipy.stats.sem(df.iloc[110:116, 17])
mean_SEPLI_pod = [mean_SEPLI_pod_delta, mean_SEPLI_pod_theta, mean_SEPLI_pod_alpha, mean_SEPLI_pod_gamma]

mean_PLI_tod_delta = statistics.mean(df.iloc[116:122, 17])
mean_PLI_tod_theta = statistics.mean(df.iloc[122:128, 17])
mean_PLI_tod_alpha = statistics.mean(df.iloc[128:134, 17])
mean_PLI_tod_gamma = statistics.mean(df.iloc[134:140, 17])
mean_PLI_tod = [mean_PLI_tod_delta, mean_PLI_tod_theta, mean_PLI_tod_alpha, mean_PLI_tod_gamma]

mean_SEPLI_tod_delta = scipy.stats.sem(df.iloc[116:122, 17])
mean_SEPLI_tod_theta = scipy.stats.sem(df.iloc[122:128, 17])
mean_SEPLI_tod_alpha = scipy.stats.sem(df.iloc[128:134, 17])
mean_SEPLI_tod_gamma = scipy.stats.sem(df.iloc[134:140, 17])
mean_SEPLI_tod = [mean_SEPLI_tod_delta, mean_SEPLI_tod_theta, mean_SEPLI_tod_alpha, mean_SEPLI_tod_gamma]

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_wPLI_pod_delta = statistics.mean(df.iloc[92:98, 19])
mean_wPLI_pod_theta = statistics.mean(df.iloc[98:104, 19])
mean_wPLI_pod_alpha = statistics.mean(df.iloc[104:110, 19])
mean_wPLI_pod_gamma = statistics.mean(df.iloc[110:116, 19])
mean_wPLI_pod = [mean_wPLI_pod_delta, mean_wPLI_pod_theta, mean_wPLI_pod_alpha, mean_wPLI_pod_gamma]

mean_SEwPLI_pod_delta = scipy.stats.sem(df.iloc[92:98, 19])
mean_SEwPLI_pod_theta = scipy.stats.sem(df.iloc[98:104, 19])
mean_SEwPLI_pod_alpha = scipy.stats.sem(df.iloc[104:110, 19])
mean_SEwPLI_pod_gamma = scipy.stats.sem(df.iloc[110:116, 19])
mean_SEwPLI_pod = [mean_SEwPLI_pod_delta, mean_SEwPLI_pod_theta, mean_SEwPLI_pod_alpha, mean_SEwPLI_pod_gamma]

mean_wPLI_tod_delta = statistics.mean(df.iloc[116:122, 19])
mean_wPLI_tod_theta = statistics.mean(df.iloc[122:128, 19])
mean_wPLI_tod_alpha = statistics.mean(df.iloc[128:134, 19])
mean_wPLI_tod_gamma = statistics.mean(df.iloc[134:140, 19])
mean_wPLI_tod = [mean_wPLI_tod_delta, mean_wPLI_tod_theta, mean_wPLI_tod_alpha, mean_wPLI_tod_gamma]

mean_SEwPLI_tod_delta = scipy.stats.sem(df.iloc[116:122, 19])
mean_SEwPLI_tod_theta = scipy.stats.sem(df.iloc[122:128, 19])
mean_SEwPLI_tod_alpha = scipy.stats.sem(df.iloc[128:134, 19])
mean_SEwPLI_tod_gamma = scipy.stats.sem(df.iloc[134:140, 19])
mean_SEwPLI_tod = [mean_SEwPLI_tod_delta, mean_SEwPLI_tod_theta, mean_SEwPLI_tod_alpha, mean_SEwPLI_tod_gamma]

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_PLI_por_delta = statistics.mean(df.iloc[140:146, 17])
mean_PLI_por_theta = statistics.mean(df.iloc[146:152, 17])
mean_PLI_por_alpha = statistics.mean(df.iloc[152:158, 17])
mean_PLI_por_gamma = statistics.mean(df.iloc[158:164, 17])
mean_PLI_por = [mean_PLI_por_delta, mean_PLI_por_theta, mean_PLI_por_alpha, mean_PLI_por_gamma]

mean_SEPLI_por_delta = scipy.stats.sem(df.iloc[140:146, 17])
mean_SEPLI_por_theta = scipy.stats.sem(df.iloc[146:152, 17])
mean_SEPLI_por_alpha = scipy.stats.sem(df.iloc[152:158, 17])
mean_SEPLI_por_gamma = scipy.stats.sem(df.iloc[158:164, 17])
mean_SEPLI_por = [mean_SEPLI_por_delta, mean_SEPLI_por_theta, mean_SEPLI_por_alpha, mean_SEPLI_por_gamma]

mean_PLI_tor_delta = statistics.mean(df.iloc[164:170, 17])
mean_PLI_tor_theta = statistics.mean(df.iloc[170:176, 17])
mean_PLI_tor_alpha = statistics.mean(df.iloc[176:182, 17])
mean_PLI_tor_gamma = statistics.mean(df.iloc[182:188, 17])
mean_PLI_tor = [mean_PLI_tor_delta, mean_PLI_tor_theta, mean_PLI_tor_alpha, mean_PLI_tor_gamma]

mean_SEPLI_tor_delta = scipy.stats.sem(df.iloc[164:170, 17])
mean_SEPLI_tor_theta = scipy.stats.sem(df.iloc[170:176, 17])
mean_SEPLI_tor_alpha = scipy.stats.sem(df.iloc[176:182, 17])
mean_SEPLI_tor_gamma = scipy.stats.sem(df.iloc[182:188, 17])
mean_SEPLI_tor = [mean_SEPLI_tor_delta, mean_SEPLI_tor_theta, mean_SEPLI_tor_alpha, mean_SEPLI_tor_gamma]

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_wPLI_por_delta = statistics.mean(df.iloc[140:146, 19])
mean_wPLI_por_theta = statistics.mean(df.iloc[146:152, 19])
mean_wPLI_por_alpha = statistics.mean(df.iloc[152:158, 19])
mean_wPLI_por_gamma = statistics.mean(df.iloc[158:164, 19])
mean_wPLI_por = [mean_wPLI_por_delta, mean_wPLI_por_theta, mean_wPLI_por_alpha, mean_wPLI_por_gamma]

mean_SEwPLI_por_delta = scipy.stats.sem(df.iloc[140:146, 19])
mean_SEwPLI_por_theta = scipy.stats.sem(df.iloc[146:152, 19])
mean_SEwPLI_por_alpha = scipy.stats.sem(df.iloc[152:158, 19])
mean_SEwPLI_por_gamma = scipy.stats.sem(df.iloc[158:164, 19])
mean_SEwPLI_por = [mean_SEwPLI_por_delta, mean_SEwPLI_por_theta, mean_SEwPLI_por_alpha, mean_SEwPLI_por_gamma]

mean_wPLI_tor_delta = statistics.mean(df.iloc[164:170, 19])
mean_wPLI_tor_theta = statistics.mean(df.iloc[170:176, 19])
mean_wPLI_tor_alpha = statistics.mean(df.iloc[176:182, 19])
mean_wPLI_tor_gamma = statistics.mean(df.iloc[182:188, 19])
mean_wPLI_tor = [mean_wPLI_tor_delta, mean_wPLI_tor_theta, mean_wPLI_tor_alpha, mean_wPLI_tor_gamma]

mean_SEwPLI_tor_delta = scipy.stats.sem(df.iloc[164:170, 19])
mean_SEwPLI_tor_theta = scipy.stats.sem(df.iloc[170:176, 19])
mean_SEwPLI_tor_alpha = scipy.stats.sem(df.iloc[176:182, 19])
mean_SEwPLI_tor_gamma = scipy.stats.sem(df.iloc[182:188, 19])
mean_SEwPLI_tor = [mean_SEwPLI_tor_delta, mean_SEwPLI_tor_theta, mean_SEwPLI_tor_alpha, mean_SEwPLI_tor_gamma]

# %%
fig, axes = plt.subplots(nrows=5, ncols=2, figsize=(15, 20), constrained_layout=True)
axes[0,0].scatter(frequency_pcn, PLI_pcn, label='phasic CN')
axes[0,0].scatter(frequency_phc, PLI_phc, label='phasic HC')
axes[0,0].scatter(frequency_pod, PLI_pod, label='phasic OD')
axes[0,0].scatter(frequency_por, PLI_por, label='phasic OR')
axes[0,0].scatter(frequency_tcn, PLI_tcn, label='tonic CN')
axes[0,0].scatter(frequency_thc, PLI_thc, label='tonic HC')
axes[0,0].scatter(frequency_tod, PLI_tod, label='tonic OD')
axes[0,0].scatter(frequency_tor, PLI_tor, label='tonic OR')
axes[0,0].legend()
axes[0,0].set_xlabel('frequency bin')
axes[0,0].set_ylabel('PLI')

axes[0,1].scatter(frequency_pcn, wPLI_pcn, label='phasic CN')
axes[0,1].scatter(frequency_phc, wPLI_phc, label='phasic HC')
axes[0,1].scatter(frequency_pod, wPLI_pod, label='phasic OD')
axes[0,1].scatter(frequency_por, wPLI_por, label='phasic OR')
axes[0,1].scatter(frequency_tcn, wPLI_tcn, label='tonic CN')
axes[0,1].scatter(frequency_thc, wPLI_thc, label='tonic HC')
axes[0,1].scatter(frequency_tod, wPLI_tod, label='tonic OD')
axes[0,1].scatter(frequency_tor, wPLI_tor, label='tonic OR')
axes[0,1].legend()
axes[0,1].set_xlabel('frequency bin')
axes[0,1].set_ylabel('wPLI')

axes[1,0].scatter(frequency_pcn, PLI_pcn, label='phasic CN')
axes[1,0].errorbar(frequencies, mean_PLI_pcn, mean_SEPLI_pcn, fmt="v", color = 'black', label='mean')
axes[1,0].scatter(frequency_tcn, PLI_tcn, label='tonic CN')
axes[1,0].errorbar(frequencies, mean_PLI_tcn, mean_SEPLI_tcn, fmt="v", color = 'black')
axes[1,0].legend()
axes[1,0].set_xlabel('frequency bin')
axes[1,0].set_ylabel('PLI')

axes[1,1].scatter(frequency_pcn, wPLI_pcn, label='phasic CN')
axes[1,1].errorbar(frequencies, mean_wPLI_pcn, mean_SEwPLI_pcn, fmt="v", color = 'black', label='mean')
axes[1,1].scatter(frequency_tcn, wPLI_tcn, label='tonic CN')
axes[1,1].errorbar(frequencies, mean_wPLI_tcn, mean_SEwPLI_tcn, fmt="v", color = 'black')
axes[1,1].legend()
axes[1,1].set_xlabel('frequency bin')
axes[1,1].set_ylabel('wPLI')

axes[2,0].scatter(frequency_phc, PLI_phc, label='phasic HC')
axes[2,0].errorbar(frequencies, mean_PLI_phc, mean_SEPLI_phc, fmt="v", color = 'black', label='mean')
axes[2,0].scatter(frequency_thc, PLI_thc, label='tonic HC')
axes[2,0].errorbar(frequencies, mean_PLI_thc, mean_SEPLI_thc, fmt="v", color = 'black')
axes[2,0].legend()
axes[2,0].set_xlabel('frequency bin')
axes[2,0].set_ylabel('PLI')

axes[2,1].scatter(frequency_phc, wPLI_phc, label='phasic HC')
axes[2,0].errorbar(frequencies, mean_wPLI_phc, mean_SEwPLI_phc, fmt="v", color = 'black', label='mean')
axes[2,1].scatter(frequency_thc, wPLI_thc, label='tonic HC')
axes[2,1].errorbar(frequencies, mean_wPLI_thc, mean_SEwPLI_thc, fmt="v", color = 'black')
axes[2,1].legend()
axes[2,1].set_xlabel('frequency bin')
axes[2,1].set_ylabel('wPLI')

axes[3,0].scatter(frequency_pod, PLI_pod, label='phasic OD')
axes[3,0].errorbar(frequencies, mean_PLI_pod, mean_SEPLI_pod, fmt="v", color = 'black')
axes[3,0].scatter(frequency_tod, PLI_tod, label='tonic OD')
axes[3,0].errorbar(frequencies, mean_PLI_tod, mean_SEPLI_tod, fmt="v", color = 'black')
axes[3,0].legend()
axes[3,0].set_xlabel('frequency bin')
axes[3,0].set_ylabel('PLI')

axes[3,1].scatter(frequency_pod, wPLI_pod, label='phasic OD')
axes[3,1].errorbar(frequencies, mean_wPLI_pod, mean_SEwPLI_pod, fmt="v", color = 'black')
axes[3,1].scatter(frequency_tod, wPLI_tod, label='tonic OD')
axes[3,1].errorbar(frequencies, mean_wPLI_tod, mean_SEwPLI_tod, fmt="v", color = 'black')
axes[3,1].legend()
axes[3,1].set_xlabel('frequency bin')
axes[3,1].set_ylabel('wPLI')

axes[4,0].scatter(frequency_por, PLI_por, label='phasic OR')
axes[4,0].errorbar(frequencies, mean_PLI_por, mean_SEPLI_por, fmt="v", color = 'black')
axes[4,0].scatter(frequency_tor, PLI_tor, label='tonic OR')
axes[4,0].errorbar(frequencies, mean_PLI_tor, mean_SEPLI_tor, fmt="v", color = 'black')
axes[4,0].legend()
axes[4,0].set_xlabel('frequency bin')
axes[4,0].set_ylabel('PLI')

axes[4,1].scatter(frequency_por, wPLI_por, label='phasic OR')
axes[4,1].errorbar(frequencies, mean_wPLI_por, mean_SEwPLI_por, fmt="v", color = 'black')
axes[4,1].scatter(frequency_tor, wPLI_tor, label='tonic OR')
axes[4,1].errorbar(frequencies, mean_wPLI_tor, mean_SEwPLI_tor, fmt="v", color = 'black')
axes[4,1].legend()
axes[4,1].set_xlabel('frequency bin')
axes[4,1].set_ylabel('wPLI')
# Out:
# Text(0, 0.5, 'wPLI')

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_DSPLI_pcn_delta = statistics.mean(df.iloc[0:6, 21])
mean_DSPLI_pcn_theta = statistics.mean(df.iloc[6:12, 21])
mean_DSPLI_pcn_alpha = statistics.mean(df.iloc[12:18, 21])
mean_DSPLI_pcn_gamma = statistics.mean(df.iloc[18:24, 21])
mean_DSPLI_pcn = [mean_DSPLI_pcn_delta, mean_DSPLI_pcn_theta, mean_DSPLI_pcn_alpha, mean_DSPLI_pcn_gamma]

mean_SEDSPLI_pcn_delta = scipy.stats.sem(df.iloc[0:6, 21])
mean_SEDSPLI_pcn_theta = scipy.stats.sem(df.iloc[6:12, 21])
mean_SEDSPLI_pcn_alpha = scipy.stats.sem(df.iloc[12:18, 21])
mean_SEDSPLI_pcn_gamma = scipy.stats.sem(df.iloc[18:24, 21])
mean_SEDSPLI_pcn = [mean_SEDSPLI_pcn_delta, mean_SEDSPLI_pcn_theta, mean_SEDSPLI_pcn_alpha, mean_SEDSPLI_pcn_gamma]

mean_DSPLI_tcn_delta = statistics.mean(df.iloc[24:30, 21])
mean_DSPLI_tcn_theta = statistics.mean(df.iloc[30:36, 21])
mean_DSPLI_tcn_alpha = statistics.mean(df.iloc[36:42, 21])
mean_DSPLI_tcn_gamma = statistics.mean(df.iloc[42:48, 21])
mean_DSPLI_tcn = [mean_DSPLI_tcn_delta, mean_DSPLI_tcn_theta, mean_DSPLI_tcn_alpha, mean_DSPLI_tcn_gamma]

mean_SEDSPLI_tcn_delta = scipy.stats.sem(df.iloc[24:30, 21])
mean_SEDSPLI_tcn_theta = scipy.stats.sem(df.iloc[30:36, 21])
mean_SEDSPLI_tcn_alpha = scipy.stats.sem(df.iloc[36:42, 21])
mean_SEDSPLI_tcn_gamma = scipy.stats.sem(df.iloc[42:48, 21])
mean_SEDSPLI_tcn = [mean_SEDSPLI_tcn_delta, mean_SEDSPLI_tcn_theta, mean_SEDSPLI_tcn_alpha, mean_SEDSPLI_tcn_gamma]

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_wDSPLI_pcn_delta = statistics.mean(df.iloc[0:6, 23])
mean_wDSPLI_pcn_theta = statistics.mean(df.iloc[6:12, 23])
mean_wDSPLI_pcn_alpha = statistics.mean(df.iloc[12:18, 23])
mean_wDSPLI_pcn_gamma = statistics.mean(df.iloc[18:24, 23])
mean_wDSPLI_pcn = [mean_wDSPLI_pcn_delta, mean_wDSPLI_pcn_theta, mean_wDSPLI_pcn_alpha, mean_wDSPLI_pcn_gamma]

mean_SEwDSPLI_pcn_delta = scipy.stats.sem(df.iloc[0:6, 23])
mean_SEwDSPLI_pcn_theta = scipy.stats.sem(df.iloc[6:12, 23])
mean_SEwDSPLI_pcn_alpha = scipy.stats.sem(df.iloc[12:18, 23])
mean_SEwDSPLI_pcn_gamma = scipy.stats.sem(df.iloc[18:24, 23])
mean_SEwDSPLI_pcn = [mean_SEwDSPLI_pcn_delta, mean_SEwDSPLI_pcn_theta, mean_SEwDSPLI_pcn_alpha, mean_SEwDSPLI_pcn_gamma]

mean_wDSPLI_tcn_delta = statistics.mean(df.iloc[24:30, 23])
mean_wDSPLI_tcn_theta = statistics.mean(df.iloc[30:36, 23])
mean_wDSPLI_tcn_alpha = statistics.mean(df.iloc[36:42, 23])
mean_wDSPLI_tcn_gamma = statistics.mean(df.iloc[42:48, 23])
mean_wDSPLI_tcn = [mean_wDSPLI_tcn_delta, mean_wDSPLI_tcn_theta, mean_wDSPLI_tcn_alpha, mean_wDSPLI_tcn_gamma]

mean_SEwDSPLI_tcn_delta = scipy.stats.sem(df.iloc[24:30, 23])
mean_SEwDSPLI_tcn_theta = scipy.stats.sem(df.iloc[30:36, 23])
mean_SEwDSPLI_tcn_alpha = scipy.stats.sem(df.iloc[36:42, 23])
mean_SEwDSPLI_tcn_gamma = scipy.stats.sem(df.iloc[42:48, 23])
mean_SEwDSPLI_tcn = [mean_SEwDSPLI_tcn_delta, mean_SEwDSPLI_tcn_theta, mean_SEwDSPLI_tcn_alpha, mean_SEwDSPLI_tcn_gamma]

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_DSPLI_phc_delta = statistics.mean(df.iloc[48:53, 21])
mean_DSPLI_phc_theta = statistics.mean(df.iloc[53:58, 21])
mean_DSPLI_phc_alpha = statistics.mean(df.iloc[58:63, 21])
mean_DSPLI_phc_gamma = statistics.mean(df.iloc[63:68, 21])
mean_DSPLI_phc = [mean_DSPLI_phc_delta, mean_DSPLI_phc_theta, mean_DSPLI_phc_alpha, mean_DSPLI_phc_gamma]

mean_SEDSPLI_phc_delta = scipy.stats.sem(df.iloc[48:53, 21])
mean_SEDSPLI_phc_theta = scipy.stats.sem(df.iloc[53:58, 21])
mean_SEDSPLI_phc_alpha = scipy.stats.sem(df.iloc[58:63, 21])
mean_SEDSPLI_phc_gamma = scipy.stats.sem(df.iloc[63:68, 21])
mean_SEDSPLI_phc = [mean_SEDSPLI_phc_delta, mean_SEDSPLI_phc_theta, mean_SEDSPLI_phc_alpha, mean_SEDSPLI_phc_gamma]

mean_DSPLI_thc_delta = statistics.mean(df.iloc[68:74, 21])
mean_DSPLI_thc_theta = statistics.mean(df.iloc[74:80, 21])
mean_DSPLI_thc_alpha = statistics.mean(df.iloc[80:86, 21])
mean_DSPLI_thc_gamma = statistics.mean(df.iloc[86:92, 21])
mean_DSPLI_thc = [mean_DSPLI_thc_delta, mean_DSPLI_thc_theta, mean_DSPLI_thc_alpha, mean_DSPLI_thc_gamma]

mean_SEDSPLI_thc_delta = scipy.stats.sem(df.iloc[68:74, 21])
mean_SEDSPLI_thc_theta = scipy.stats.sem(df.iloc[74:80, 21])
mean_SEDSPLI_thc_alpha = scipy.stats.sem(df.iloc[80:86, 21])
mean_SEDSPLI_thc_gamma = scipy.stats.sem(df.iloc[86:92, 21])
mean_SEDSPLI_thc = [mean_SEDSPLI_thc_delta, mean_SEDSPLI_thc_theta, mean_SEDSPLI_thc_alpha, mean_SEDSPLI_thc_gamma]

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_wDSPLI_phc_delta = statistics.mean(df.iloc[48:53, 23])
mean_wDSPLI_phc_theta = statistics.mean(df.iloc[53:58, 23])
mean_wDSPLI_phc_alpha = statistics.mean(df.iloc[58:63, 23])
mean_wDSPLI_phc_gamma = statistics.mean(df.iloc[63:68, 23])
mean_wDSPLI_phc = [mean_wDSPLI_phc_delta, mean_wDSPLI_phc_theta, mean_wDSPLI_phc_alpha, mean_wDSPLI_phc_gamma]

mean_SEwDSPLI_phc_delta = scipy.stats.sem(df.iloc[48:53, 23])
mean_SEwDSPLI_phc_theta = scipy.stats.sem(df.iloc[53:58, 23])
mean_SEwDSPLI_phc_alpha = scipy.stats.sem(df.iloc[58:63, 23])
mean_SEwDSPLI_phc_gamma = scipy.stats.sem(df.iloc[63:68, 23])
mean_SEwDSPLI_phc = [mean_SEwDSPLI_phc_delta, mean_SEwDSPLI_phc_theta, mean_SEwDSPLI_phc_alpha, mean_SEwDSPLI_phc_gamma]

mean_wDSPLI_thc_delta = statistics.mean(df.iloc[68:74, 23])
mean_wDSPLI_thc_theta = statistics.mean(df.iloc[74:80, 23])
mean_wDSPLI_thc_alpha = statistics.mean(df.iloc[80:86, 23])
mean_wDSPLI_thc_gamma = statistics.mean(df.iloc[86:92, 23])
mean_wDSPLI_thc = [mean_wDSPLI_thc_delta, mean_wDSPLI_thc_theta, mean_wDSPLI_thc_alpha, mean_wDSPLI_thc_gamma]

mean_SEwDSPLI_thc_delta = scipy.stats.sem(df.iloc[68:74, 23])
mean_SEwDSPLI_thc_theta = scipy.stats.sem(df.iloc[74:80, 23])
mean_SEwDSPLI_thc_alpha = scipy.stats.sem(df.iloc[80:86, 23])
mean_SEwDSPLI_thc_gamma = scipy.stats.sem(df.iloc[86:92, 23])
mean_SEwDSPLI_thc = [mean_SEwDSPLI_thc_delta, mean_SEwDSPLI_thc_theta, mean_SEwDSPLI_thc_alpha, mean_SEwDSPLI_thc_gamma]

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_DSPLI_pod_delta = statistics.mean(df.iloc[92:98, 21])
mean_DSPLI_pod_theta = statistics.mean(df.iloc[98:104, 21])
mean_DSPLI_pod_alpha = statistics.mean(df.iloc[104:110, 21])
mean_DSPLI_pod_gamma = statistics.mean(df.iloc[110:116, 21])
mean_DSPLI_pod = [mean_DSPLI_pod_delta, mean_DSPLI_pod_theta, mean_DSPLI_pod_alpha, mean_DSPLI_pod_gamma]

mean_SEDSPLI_pod_delta = scipy.stats.sem(df.iloc[92:98, 21])
mean_SEDSPLI_pod_theta = scipy.stats.sem(df.iloc[98:104, 21])
mean_SEDSPLI_pod_alpha = scipy.stats.sem(df.iloc[104:110, 21])
mean_SEDSPLI_pod_gamma = scipy.stats.sem(df.iloc[110:116, 21])
mean_SEDSPLI_pod = [mean_SEDSPLI_pod_delta, mean_SEDSPLI_pod_theta, mean_SEDSPLI_pod_alpha, mean_SEDSPLI_pod_gamma]

mean_DSPLI_tod_delta = statistics.mean(df.iloc[116:122, 21])
mean_DSPLI_tod_theta = statistics.mean(df.iloc[122:128, 21])
mean_DSPLI_tod_alpha = statistics.mean(df.iloc[128:134, 21])
mean_DSPLI_tod_gamma = statistics.mean(df.iloc[134:140, 21])
mean_DSPLI_tod = [mean_DSPLI_tod_delta, mean_DSPLI_tod_theta, mean_DSPLI_tod_alpha, mean_DSPLI_tod_gamma]

mean_SEDSPLI_tod_delta = scipy.stats.sem(df.iloc[116:122, 21])
mean_SEDSPLI_tod_theta = scipy.stats.sem(df.iloc[122:128, 21])
mean_SEDSPLI_tod_alpha = scipy.stats.sem(df.iloc[128:134, 21])
mean_SEDSPLI_tod_gamma = scipy.stats.sem(df.iloc[134:140, 21])
mean_SEDSPLI_tod = [mean_SEDSPLI_tod_delta, mean_SEDSPLI_tod_theta, mean_SEDSPLI_tod_alpha, mean_SEDSPLI_tod_gamma]

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_wDSPLI_pod_delta = statistics.mean(df.iloc[92:98, 23])
mean_wDSPLI_pod_theta = statistics.mean(df.iloc[98:104, 23])
mean_wDSPLI_pod_alpha = statistics.mean(df.iloc[104:110, 23])
mean_wDSPLI_pod_gamma = statistics.mean(df.iloc[110:116, 23])
mean_wDSPLI_pod = [mean_wDSPLI_pod_delta, mean_wDSPLI_pod_theta, mean_wDSPLI_pod_alpha, mean_wDSPLI_pod_gamma]

mean_SEwDSPLI_pod_delta = scipy.stats.sem(df.iloc[92:98, 23])
mean_SEwDSPLI_pod_theta = scipy.stats.sem(df.iloc[98:104, 23])
mean_SEwDSPLI_pod_alpha = scipy.stats.sem(df.iloc[104:110, 23])
mean_SEwDSPLI_pod_gamma = scipy.stats.sem(df.iloc[110:116, 23])
mean_SEwDSPLI_pod = [mean_SEwDSPLI_pod_delta, mean_SEwDSPLI_pod_theta, mean_SEwDSPLI_pod_alpha, mean_SEwDSPLI_pod_gamma]

mean_wDSPLI_tod_delta = statistics.mean(df.iloc[116:122, 23])
mean_wDSPLI_tod_theta = statistics.mean(df.iloc[122:128, 23])
mean_wDSPLI_tod_alpha = statistics.mean(df.iloc[128:134, 23])
mean_wDSPLI_tod_gamma = statistics.mean(df.iloc[134:140, 23])
mean_wDSPLI_tod = [mean_wDSPLI_tod_delta, mean_wDSPLI_tod_theta, mean_wDSPLI_tod_alpha, mean_wDSPLI_tod_gamma]

mean_SEwDSPLI_tod_delta = scipy.stats.sem(df.iloc[116:122, 23])
mean_SEwDSPLI_tod_theta = scipy.stats.sem(df.iloc[122:128, 23])
mean_SEwDSPLI_tod_alpha = scipy.stats.sem(df.iloc[128:134, 23])
mean_SEwDSPLI_tod_gamma = scipy.stats.sem(df.iloc[134:140, 23])
mean_SEwDSPLI_tod = [mean_SEwDSPLI_tod_delta, mean_SEwDSPLI_tod_theta, mean_SEwDSPLI_tod_alpha, mean_SEwDSPLI_tod_gamma]

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_DSPLI_por_delta = statistics.mean(df.iloc[140:146, 21])
mean_DSPLI_por_theta = statistics.mean(df.iloc[146:152, 21])
mean_DSPLI_por_alpha = statistics.mean(df.iloc[152:158, 21])
mean_DSPLI_por_gamma = statistics.mean(df.iloc[158:164, 21])
mean_DSPLI_por = [mean_DSPLI_por_delta, mean_DSPLI_por_theta, mean_DSPLI_por_alpha, mean_DSPLI_por_gamma]

mean_SEDSPLI_por_delta = scipy.stats.sem(df.iloc[140:146, 21])
mean_SEDSPLI_por_theta = scipy.stats.sem(df.iloc[146:152, 21])
mean_SEDSPLI_por_alpha = scipy.stats.sem(df.iloc[152:158, 21])
mean_SEDSPLI_por_gamma = scipy.stats.sem(df.iloc[158:164, 21])
mean_SEDSPLI_por = [mean_SEDSPLI_por_delta, mean_SEDSPLI_por_theta, mean_SEDSPLI_por_alpha, mean_SEDSPLI_por_gamma]

mean_DSPLI_tor_delta = statistics.mean(df.iloc[164:170, 21])
mean_DSPLI_tor_theta = statistics.mean(df.iloc[170:176, 21])
mean_DSPLI_tor_alpha = statistics.mean(df.iloc[176:182, 21])
mean_DSPLI_tor_gamma = statistics.mean(df.iloc[182:188, 21])
mean_DSPLI_tor = [mean_DSPLI_tor_delta, mean_DSPLI_tor_theta, mean_DSPLI_tor_alpha, mean_DSPLI_tor_gamma]

mean_SEDSPLI_tor_delta = scipy.stats.sem(df.iloc[164:170, 21])
mean_SEDSPLI_tor_theta = scipy.stats.sem(df.iloc[170:176, 21])
mean_SEDSPLI_tor_alpha = scipy.stats.sem(df.iloc[176:182, 21])
mean_SEDSPLI_tor_gamma = scipy.stats.sem(df.iloc[182:188, 21])
mean_SEDSPLI_tor = [mean_SEDSPLI_tor_delta, mean_SEDSPLI_tor_theta, mean_SEDSPLI_tor_alpha, mean_SEDSPLI_tor_gamma]

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_wDSPLI_por_delta = statistics.mean(df.iloc[140:146, 23])
mean_wDSPLI_por_theta = statistics.mean(df.iloc[146:152, 23])
mean_wDSPLI_por_alpha = statistics.mean(df.iloc[152:158, 23])
mean_wDSPLI_por_gamma = statistics.mean(df.iloc[158:164, 23])
mean_wDSPLI_por = [mean_wDSPLI_por_delta, mean_wDSPLI_por_theta, mean_wDSPLI_por_alpha, mean_wDSPLI_por_gamma]

mean_SEwDSPLI_por_delta = scipy.stats.sem(df.iloc[140:146, 23])
mean_SEwDSPLI_por_theta = scipy.stats.sem(df.iloc[146:152, 23])
mean_SEwDSPLI_por_alpha = scipy.stats.sem(df.iloc[152:158, 23])
mean_SEwDSPLI_por_gamma = scipy.stats.sem(df.iloc[158:164, 23])
mean_SEwDSPLI_por = [mean_SEwDSPLI_por_delta, mean_SEwDSPLI_por_theta, mean_SEwDSPLI_por_alpha, mean_SEwDSPLI_por_gamma]

mean_wDSPLI_tor_delta = statistics.mean(df.iloc[164:170, 23])
mean_wDSPLI_tor_theta = statistics.mean(df.iloc[170:176, 23])
mean_wDSPLI_tor_alpha = statistics.mean(df.iloc[176:182, 23])
mean_wDSPLI_tor_gamma = statistics.mean(df.iloc[182:188, 23])
mean_wDSPLI_tor = [mean_wDSPLI_tor_delta, mean_wDSPLI_tor_theta, mean_wDSPLI_tor_alpha, mean_wDSPLI_tor_gamma]

mean_SEwDSPLI_tor_delta = scipy.stats.sem(df.iloc[164:170, 23])
mean_SEwDSPLI_tor_theta = scipy.stats.sem(df.iloc[170:176, 23])
mean_SEwDSPLI_tor_alpha = scipy.stats.sem(df.iloc[176:182, 23])
mean_SEwDSPLI_tor_gamma = scipy.stats.sem(df.iloc[182:188, 23])
mean_SEwDSPLI_tor = [mean_SEwDSPLI_tor_delta, mean_SEwDSPLI_tor_theta, mean_SEwDSPLI_tor_alpha, mean_SEwDSPLI_tor_gamma]

# %%
fig, axes = plt.subplots(nrows=5, ncols=2, figsize=(15, 20), constrained_layout=True)
axes[0,0].scatter(frequency_pcn, DSPLI_pcn, label='phasic CN')
axes[0,0].scatter(frequency_phc, DSPLI_phc, label='phasic HC')
axes[0,0].scatter(frequency_pod, DSPLI_pod, label='phasic OD')
axes[0,0].scatter(frequency_por, DSPLI_por, label='phasic OR')
axes[0,0].scatter(frequency_tcn, DSPLI_tcn, label='tonic CN')
axes[0,0].scatter(frequency_thc, DSPLI_thc, label='tonic HC')
axes[0,0].scatter(frequency_tod, DSPLI_tod, label='tonic OD')
axes[0,0].scatter(frequency_tor, DSPLI_tor, label='tonic OR')
axes[0,0].legend()
axes[0,0].set_xlabel('frequency bin')
axes[0,0].set_ylabel('DSPLI')

axes[0,1].scatter(frequency_pcn, wDSPLI_pcn, label='phasic CN')
axes[0,1].scatter(frequency_phc, wDSPLI_phc, label='phasic HC')
axes[0,1].scatter(frequency_pod, wDSPLI_pod, label='phasic OD')
axes[0,1].scatter(frequency_por, wDSPLI_por, label='phasic OR')
axes[0,1].scatter(frequency_tcn, wDSPLI_tcn, label='tonic CN')
axes[0,1].scatter(frequency_thc, wDSPLI_thc, label='tonic HC')
axes[0,1].scatter(frequency_tod, wDSPLI_tod, label='tonic OD')
axes[0,1].scatter(frequency_tor, wDSPLI_tor, label='tonic OR')
axes[0,1].legend()
axes[0,1].set_xlabel('frequency bin')
axes[0,1].set_ylabel('wDSPLI')

axes[1,0].scatter(frequency_pcn, DSPLI_pcn, label='phasic CN')
axes[1,0].errorbar(frequencies, mean_DSPLI_pcn, mean_SEDSPLI_pcn, fmt="v", color = 'black', label='mean')
axes[1,0].scatter(frequency_tcn, DSPLI_tcn, label='tonic CN')
axes[1,0].errorbar(frequencies, mean_DSPLI_tcn, mean_SEDSPLI_tcn, fmt="v", color = 'black')
axes[1,0].legend()
axes[1,0].set_xlabel('frequency bin')
axes[1,0].set_ylabel('DSPLI')

axes[1,1].scatter(frequency_pcn, wDSPLI_pcn, label='phasic CN')
axes[1,1].errorbar(frequencies, mean_wDSPLI_pcn, mean_SEwDSPLI_pcn, fmt="v", color = 'black', label='mean')
axes[1,1].scatter(frequency_tcn, wDSPLI_tcn, label='tonic CN')
axes[1,1].errorbar(frequencies, mean_wDSPLI_tcn, mean_SEwDSPLI_tcn, fmt="v", color = 'black')
axes[1,1].legend()
axes[1,1].set_xlabel('frequency bin')
axes[1,1].set_ylabel('wDSPLI')

axes[2,0].scatter(frequency_phc, DSPLI_phc, label='phasic HC')
axes[2,0].errorbar(frequencies, mean_DSPLI_phc, mean_SEDSPLI_phc, fmt="v", color = 'black', label='mean')
axes[2,0].scatter(frequency_thc, DSPLI_thc, label='tonic HC')
axes[2,0].errorbar(frequencies, mean_DSPLI_thc, mean_SEDSPLI_thc, fmt="v", color = 'black')
axes[2,0].legend()
axes[2,0].set_xlabel('frequency bin')
axes[2,0].set_ylabel('DSPLI')

axes[2,1].scatter(frequency_phc, wDSPLI_phc, label='phasic HC')
axes[2,1].errorbar(frequencies, mean_wDSPLI_phc, mean_SEwDSPLI_phc, fmt="v", color = 'black', label='mean')
axes[2,1].scatter(frequency_thc, wDSPLI_thc, label='tonic HC')
axes[2,1].errorbar(frequencies, mean_wDSPLI_thc, mean_SEwDSPLI_thc, fmt="v", color = 'black')
axes[2,1].legend()
axes[2,1].set_xlabel('frequency bin')
axes[2,1].set_ylabel('wDSPLI')

axes[3,0].scatter(frequency_pod, DSPLI_pod, label='phasic OD')
axes[3,0].errorbar(frequencies, mean_DSPLI_pod, mean_SEDSPLI_pod, fmt="v", color = 'black')
axes[3,0].scatter(frequency_tod, DSPLI_tod, label='tonic OD')
axes[3,0].errorbar(frequencies, mean_DSPLI_tod, mean_SEDSPLI_tod, fmt="v", color = 'black')
axes[3,0].legend()
axes[3,0].set_xlabel('frequency bin')
axes[3,0].set_ylabel('DSPLI')

axes[3,1].scatter(frequency_pod, wDSPLI_pod, label='phasic OD')
axes[3,1].errorbar(frequencies, mean_wDSPLI_pod, mean_SEwDSPLI_pod, fmt="v", color = 'black')
axes[3,1].scatter(frequency_tod, wDSPLI_tod, label='tonic OD')
axes[3,1].errorbar(frequencies, mean_wDSPLI_tod, mean_SEwDSPLI_tod, fmt="v", color = 'black')
axes[3,1].legend()
axes[3,1].set_xlabel('frequency bin')
axes[3,1].set_ylabel('wDSPLI')

axes[4,0].scatter(frequency_por, DSPLI_por, label='phasic OR')
axes[4,0].errorbar(frequencies, mean_DSPLI_por, mean_SEDSPLI_por, fmt="v", color = 'black')
axes[4,0].scatter(frequency_tor, DSPLI_tor, label='tonic OR')
axes[4,0].errorbar(frequencies, mean_DSPLI_tor, mean_SEDSPLI_tor, fmt="v", color = 'black')
axes[4,0].legend()
axes[4,0].set_xlabel('frequency bin')
axes[4,0].set_ylabel('DSPLI')

axes[4,1].scatter(frequency_por, wDSPLI_por, label='phasic OR')
axes[4,1].errorbar(frequencies, mean_wDSPLI_por, mean_SEwDSPLI_por, fmt="v", color = 'black')
axes[4,1].scatter(frequency_tor, wDSPLI_tor, label='tonic OR')
axes[4,1].errorbar(frequencies, mean_wDSPLI_tor, mean_SEwDSPLI_tor, fmt="v", color = 'black')
axes[4,1].legend()
axes[4,1].set_xlabel('frequency bin')
axes[4,1].set_ylabel('wDSPLI')
# Out:
# Text(0, 0.5, 'wDSPLI')

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_PPC_pcn_delta = statistics.mean(df.iloc[0:6, 25])
mean_PPC_pcn_theta = statistics.mean(df.iloc[6:12, 25])
mean_PPC_pcn_alpha = statistics.mean(df.iloc[12:18, 25])
mean_PPC_pcn_gamma = statistics.mean(df.iloc[18:24, 25])
mean_PPC_pcn = [mean_PPC_pcn_delta, mean_PPC_pcn_theta, mean_PPC_pcn_alpha, mean_PPC_pcn_gamma]

mean_SEPPC_pcn_delta = scipy.stats.sem(df.iloc[0:6, 25])
mean_SEPPC_pcn_theta = scipy.stats.sem(df.iloc[6:12, 25])
mean_SEPPC_pcn_alpha = scipy.stats.sem(df.iloc[12:18, 25])
mean_SEPPC_pcn_gamma = scipy.stats.sem(df.iloc[18:24, 25])
mean_SEPPC_pcn = [mean_SEPPC_pcn_delta, mean_SEPPC_pcn_theta, mean_SEPPC_pcn_alpha, mean_SEPPC_pcn_gamma]

mean_PPC_tcn_delta = statistics.mean(df.iloc[24:30, 25])
mean_PPC_tcn_theta = statistics.mean(df.iloc[30:36, 25])
mean_PPC_tcn_alpha = statistics.mean(df.iloc[36:42, 25])
mean_PPC_tcn_gamma = statistics.mean(df.iloc[42:48, 25])
mean_PPC_tcn = [mean_PPC_tcn_delta, mean_PPC_tcn_theta, mean_PPC_tcn_alpha, mean_PPC_tcn_gamma]

mean_SEPPC_tcn_delta = scipy.stats.sem(df.iloc[24:30, 25])
mean_SEPPC_tcn_theta = scipy.stats.sem(df.iloc[30:36, 25])
mean_SEPPC_tcn_alpha = scipy.stats.sem(df.iloc[36:42, 25])
mean_SEPPC_tcn_gamma = scipy.stats.sem(df.iloc[42:48, 25])
mean_SEPPC_tcn = [mean_SEPPC_tcn_delta, mean_SEPPC_tcn_theta, mean_SEPPC_tcn_alpha, mean_SEPPC_tcn_gamma]

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_PPC_phc_delta = statistics.mean(df.iloc[48:53, 25])
mean_PPC_phc_theta = statistics.mean(df.iloc[53:58, 25])
mean_PPC_phc_alpha = statistics.mean(df.iloc[58:63, 25])
mean_PPC_phc_gamma = statistics.mean(df.iloc[63:68, 25])
mean_PPC_phc = [mean_PPC_phc_delta, mean_PPC_phc_theta, mean_PPC_phc_alpha, mean_PPC_phc_gamma]

mean_SEPPC_phc_delta = scipy.stats.sem(df.iloc[48:53, 25])
mean_SEPPC_phc_theta = scipy.stats.sem(df.iloc[53:58, 25])
mean_SEPPC_phc_alpha = scipy.stats.sem(df.iloc[58:63, 25])
mean_SEPPC_phc_gamma = scipy.stats.sem(df.iloc[63:68, 25])
mean_SEPPC_phc = [mean_SEPPC_phc_delta, mean_SEPPC_phc_theta, mean_SEPPC_phc_alpha, mean_SEPPC_phc_gamma]

mean_PPC_thc_delta = statistics.mean(df.iloc[68:74, 25])
mean_PPC_thc_theta = statistics.mean(df.iloc[74:80, 25])
mean_PPC_thc_alpha = statistics.mean(df.iloc[80:86, 25])
mean_PPC_thc_gamma = statistics.mean(df.iloc[86:92, 25])
mean_PPC_thc = [mean_PPC_thc_delta, mean_PPC_thc_theta, mean_PPC_thc_alpha, mean_PPC_thc_gamma]

mean_SEPPC_thc_delta = scipy.stats.sem(df.iloc[68:74, 25])
mean_SEPPC_thc_theta = scipy.stats.sem(df.iloc[74:80, 25])
mean_SEPPC_thc_alpha = scipy.stats.sem(df.iloc[80:86, 25])
mean_SEPPC_thc_gamma = scipy.stats.sem(df.iloc[86:92, 25])
mean_SEPPC_thc = [mean_SEPPC_thc_delta, mean_SEPPC_thc_theta, mean_SEPPC_thc_alpha, mean_SEPPC_thc_gamma]

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_PPC_pod_delta = statistics.mean(df.iloc[92:98, 25])
mean_PPC_pod_theta = statistics.mean(df.iloc[98:104, 25])
mean_PPC_pod_alpha = statistics.mean(df.iloc[104:110, 25])
mean_PPC_pod_gamma = statistics.mean(df.iloc[110:116, 25])
mean_PPC_pod = [mean_PPC_pod_delta, mean_PPC_pod_theta, mean_PPC_pod_alpha, mean_PPC_pod_gamma]

mean_SEPPC_pod_delta = scipy.stats.sem(df.iloc[92:98, 25])
mean_SEPPC_pod_theta = scipy.stats.sem(df.iloc[98:104, 25])
mean_SEPPC_pod_alpha = scipy.stats.sem(df.iloc[104:110, 25])
mean_SEPPC_pod_gamma = scipy.stats.sem(df.iloc[110:116, 25])
mean_SEPPC_pod = [mean_SEPPC_pod_delta, mean_SEPPC_pod_theta, mean_SEPPC_pod_alpha, mean_SEPPC_pod_gamma]

mean_PPC_tod_delta = statistics.mean(df.iloc[116:122, 25])
mean_PPC_tod_theta = statistics.mean(df.iloc[122:128, 25])
mean_PPC_tod_alpha = statistics.mean(df.iloc[128:134, 25])
mean_PPC_tod_gamma = statistics.mean(df.iloc[134:140, 25])
mean_PPC_tod = [mean_PPC_tod_delta, mean_PPC_tod_theta, mean_PPC_tod_alpha, mean_PPC_tod_gamma]

mean_SEPPC_tod_delta = scipy.stats.sem(df.iloc[116:122, 25])
mean_SEPPC_tod_theta = scipy.stats.sem(df.iloc[122:128, 25])
mean_SEPPC_tod_alpha = scipy.stats.sem(df.iloc[128:134, 25])
mean_SEPPC_tod_gamma = scipy.stats.sem(df.iloc[134:140, 25])
mean_SEPPC_tod = [mean_SEPPC_tod_delta, mean_SEPPC_tod_theta, mean_SEPPC_tod_alpha, mean_SEPPC_tod_gamma]

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_PPC_por_delta = statistics.mean(df.iloc[140:146, 25])
mean_PPC_por_theta = statistics.mean(df.iloc[146:152, 25])
mean_PPC_por_alpha = statistics.mean(df.iloc[152:158, 25])
mean_PPC_por_gamma = statistics.mean(df.iloc[158:164, 25])
mean_PPC_por = [mean_PPC_por_delta, mean_PPC_por_theta, mean_PPC_por_alpha, mean_PPC_por_gamma]

mean_SEPPC_por_delta = scipy.stats.sem(df.iloc[140:146, 25])
mean_SEPPC_por_theta = scipy.stats.sem(df.iloc[146:152, 25])
mean_SEPPC_por_alpha = scipy.stats.sem(df.iloc[152:158, 25])
mean_SEPPC_por_gamma = scipy.stats.sem(df.iloc[158:164, 25])
mean_SEPPC_por = [mean_SEPPC_por_delta, mean_SEPPC_por_theta, mean_SEPPC_por_alpha, mean_SEPPC_por_gamma]

mean_PPC_tor_delta = statistics.mean(df.iloc[164:170, 25])
mean_PPC_tor_theta = statistics.mean(df.iloc[170:176, 25])
mean_PPC_tor_alpha = statistics.mean(df.iloc[176:182, 25])
mean_PPC_tor_gamma = statistics.mean(df.iloc[182:188, 25])
mean_PPC_tor = [mean_PPC_tor_delta, mean_PPC_tor_theta, mean_PPC_tor_alpha, mean_PPC_tor_gamma]

mean_SEPPC_tor_delta = scipy.stats.sem(df.iloc[164:170, 25])
mean_SEPPC_tor_theta = scipy.stats.sem(df.iloc[170:176, 25])
mean_SEPPC_tor_alpha = scipy.stats.sem(df.iloc[176:182, 25])
mean_SEPPC_tor_gamma = scipy.stats.sem(df.iloc[182:188, 25])
mean_SEPPC_tor = [mean_SEPPC_tor_delta, mean_SEPPC_tor_theta, mean_SEPPC_tor_alpha, mean_SEPPC_tor_gamma]

# %%
fig, axes = plt.subplots(nrows=5, ncols=1, figsize=(15, 20), constrained_layout=True)
axes[0].scatter(frequency_pcn, PPC_pcn, label='phasic CN')
axes[0].scatter(frequency_phc, PPC_phc, label='phasic HC')
axes[0].scatter(frequency_pod, PPC_pod, label='phasic OD')
axes[0].scatter(frequency_por, PPC_por, label='phasic OR')
axes[0].scatter(frequency_tcn, PPC_tcn, label='tonic CN')
axes[0].scatter(frequency_thc, PPC_thc, label='tonic HC')
axes[0].scatter(frequency_tod, PPC_tod, label='tonic OD')
axes[0].scatter(frequency_tor, PPC_tor, label='tonic OR')
axes[0].legend()
axes[0].set_xlabel('frequency bin')
axes[0].set_ylabel('PPC')

axes[1].scatter(frequency_pcn, PPC_pcn, label='phasic CN')
axes[1].errorbar(frequencies, mean_PPC_pcn, mean_SEPPC_pcn, fmt="v", color = 'black', label='mean')
axes[1].scatter(frequency_tcn, PPC_tcn, label='tonic CN')
axes[1].errorbar(frequencies, mean_PPC_tcn, mean_SEPPC_tcn, fmt="v", color = 'black')
axes[1].legend()
axes[1].set_xlabel('frequency bin')
axes[1].set_ylabel('PPC')

axes[2].scatter(frequency_phc, PPC_phc, label='phasic HC')
axes[2].errorbar(frequencies, mean_PPC_phc, mean_SEPPC_phc, fmt="v", color = 'black', label='mean')
axes[2].scatter(frequency_thc, PPC_thc, label='tonic HC')
axes[2].errorbar(frequencies, mean_PPC_thc, mean_SEPPC_thc, fmt="v", color = 'black')
axes[2].legend()
axes[2].set_xlabel('frequency bin')
axes[2].set_ylabel('PPC')

axes[3].scatter(frequency_pod, PPC_pod, label='phasic OD')
axes[3].errorbar(frequencies, mean_PPC_pod, mean_SEPPC_pod, fmt="v", color = 'black')
axes[3].scatter(frequency_tod, PPC_tod, label='tonic OD')
axes[3].errorbar(frequencies, mean_PPC_tod, mean_SEPPC_tod, fmt="v", color = 'black')
axes[3].legend()
axes[3].set_xlabel('frequency bin')
axes[3].set_ylabel('PPC')

axes[4].scatter(frequency_por, PPC_por, label='phasic OR')
axes[4].errorbar(frequencies, mean_PPC_por, mean_SEPPC_por, fmt="v", color = 'black')
axes[4].scatter(frequency_tor, PPC_tor, label='tonic OR')
axes[4].errorbar(frequencies, mean_PPC_tor, mean_SEPPC_tor, fmt="v", color = 'black')
axes[4].legend()
axes[4].set_xlabel('frequency bin')
axes[4].set_ylabel('PPC')
# Out:
# Text(0, 0.5, 'PPC')

# %% [markdown]
# ## Learning vs HC:

# %%
df2 = pd.read_excel('all_results_table_learning.xlsx')
print(df2)
# Out:
#                          Name  Data set  RatID  StudyDay Condition  Treatment  \
# 0    Rat1_SD1_CN_4_posttrial2  OS_Basic      1         1        CN          4
# 1    Rat1_SD1_CN_4_posttrial4  OS_Basic      1         1        CN          4
# 2    Rat3_SD1_CN_4_posttrial4  OS_Basic      3         1        CN          4
# 3    Rat3_SD1_CN_4_posttrial5  OS_Basic      3         1        CN          4
# 4    Rat4_SD1_CN_4_posttrial2  OS_Basic      4         1        CN          4
# ..                        ...       ...    ...       ...       ...        ...
# 139  Rat1_SD2_OR_4_posttrial4  OS_Basic      1         2        OR          4
# 140  Rat3_SD1_OR_4_posttrial4  OS_Basic      3         1        OR          4
# 141  Rat3_SD1_OR_4_posttrial5  OS_Basic      3         1        OR          4
# 142  Rat4_SD3_OR_4_posttrial4  OS_Basic      4         3        OR          4
# 143  Rat4_SD3_OR_4_posttrial5  OS_Basic      4         3        OR          4
#
# ...

# %%
#groups:
frequency_LP = np.hstack([frequency_pcn, frequency_pod, frequency_por])
frequency_LT = np.hstack([frequency_tcn, frequency_tod, frequency_tor])
frequency_ALLP = np.hstack([frequency_pcn, frequency_phc, frequency_pod, frequency_por])
frequency_ALLT = np.hstack([frequency_tcn, frequency_thc, frequency_tod, frequency_tor])

COH_LP = np.hstack([COH_pcn, COH_pod, COH_por])
COH_LT = np.hstack([COH_tcn, COH_tod, COH_tor])
iCOH_LP = np.hstack([iCOH_pcn, iCOH_pod, iCOH_por])
iCOH_LT = np.hstack([iCOH_tcn, iCOH_tod, iCOH_tor])
COH_ALLP = np.hstack([COH_pcn, COH_phc, COH_pod, COH_por])
COH_ALLT = np.hstack([COH_tcn, COH_thc, COH_tod, COH_tor])
iCOH_ALLP = np.hstack([iCOH_pcn, iCOH_phc, iCOH_pod, iCOH_por])
iCOH_ALLT = np.hstack([iCOH_tcn, iCOH_thc, iCOH_tod, iCOH_tor])

PLI_LP = np.hstack([PLI_pcn, PLI_pod, PLI_por])
PLI_LT = np.hstack([PLI_tcn, PLI_tod, PLI_tor])
wPLI_LP = np.hstack([wPLI_pcn, wPLI_pod, wPLI_por])
wPLI_LT = np.hstack([wPLI_tcn, wPLI_tod, wPLI_tor])
PLI_ALLP = np.hstack([PLI_pcn, PLI_phc, PLI_pod, PLI_por])
PLI_ALLT = np.hstack([PLI_tcn, PLI_thc, PLI_tod, PLI_tor])
wPLI_ALLP = np.hstack([wPLI_pcn, wPLI_phc, wPLI_pod, wPLI_por])
wPLI_ALLT = np.hstack([wPLI_tcn, wPLI_thc, wPLI_tod, wPLI_tor])

DSPLI_LP = np.hstack([DSPLI_pcn, DSPLI_pod, DSPLI_por])
DSPLI_LT = np.hstack([DSPLI_tcn, DSPLI_tod, DSPLI_tor])
wDSPLI_LP = np.hstack([wDSPLI_pcn, wDSPLI_pod, wDSPLI_por])
wDSPLI_LT = np.hstack([wDSPLI_tcn, wDSPLI_tod, wDSPLI_tor])
DSPLI_ALLP = np.hstack([DSPLI_pcn, DSPLI_phc, DSPLI_pod, DSPLI_por])
DSPLI_ALLT = np.hstack([DSPLI_tcn, DSPLI_thc, DSPLI_tod, DSPLI_tor])
wDSPLI_ALLP = np.hstack([wDSPLI_pcn, wDSPLI_phc, wDSPLI_pod, wDSPLI_por])
wDSPLI_ALLT = np.hstack([wDSPLI_tcn, wDSPLI_thc, wDSPLI_tod, wDSPLI_tor])

PPC_LP = np.hstack([PPC_pcn, PPC_pod, PPC_por])
PPC_LT = np.hstack([PPC_tcn, PPC_tod, PPC_tor])
PPC_ALLP = np.hstack([PPC_pcn, PPC_phc, PPC_pod, PPC_por])
PPC_ALLT = np.hstack([PPC_tcn, PPC_thc, PPC_tod, PPC_tor])

# %%
len(COH_ALLP)
# Out:
# 92

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_COH_LP_delta = statistics.mean(df2.iloc[0:18, 13])
mean_COH_LP_theta = statistics.mean(df2.iloc[18:36, 13])
mean_COH_LP_alpha = statistics.mean(df2.iloc[36:54, 13])
mean_COH_LP_gamma = statistics.mean(df2.iloc[54:72, 13])
mean_COH_LP = [mean_COH_LP_delta, mean_COH_LP_theta, mean_COH_LP_alpha, mean_COH_LP_gamma]

mean_SECOH_LP_delta = scipy.stats.sem(df2.iloc[0:18, 13])
mean_SECOH_LP_theta = scipy.stats.sem(df2.iloc[18:36, 13])
mean_SECOH_LP_alpha = scipy.stats.sem(df2.iloc[36:54, 13])
mean_SECOH_LP_gamma = scipy.stats.sem(df2.iloc[54:72, 13])
mean_SECOH_LP = [mean_SECOH_LP_delta, mean_SECOH_LP_theta, mean_SECOH_LP_alpha, mean_SECOH_LP_gamma]

mean_COH_LT_delta = statistics.mean(df2.iloc[72:90, 13])
mean_COH_LT_theta = statistics.mean(df2.iloc[90:108, 13])
mean_COH_LT_alpha = statistics.mean(df2.iloc[108:126, 13])
mean_COH_LT_gamma = statistics.mean(df2.iloc[126:144, 13])
mean_COH_LT = [mean_COH_LT_delta, mean_COH_LT_theta, mean_COH_LT_alpha, mean_COH_LT_gamma]

mean_SECOH_LT_delta = scipy.stats.sem(df2.iloc[72:90, 13])
mean_SECOH_LT_theta = scipy.stats.sem(df2.iloc[90:108, 13])
mean_SECOH_LT_alpha = scipy.stats.sem(df2.iloc[108:126, 13])
mean_SECOH_LT_gamma = scipy.stats.sem(df2.iloc[126:144, 13])
mean_SECOH_LT = [mean_SECOH_LT_delta, mean_SECOH_LT_theta, mean_SECOH_LT_alpha, mean_SECOH_LT_gamma]

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_iCOH_LP_delta = statistics.mean(df2.iloc[0:18, 15])
mean_iCOH_LP_theta = statistics.mean(df2.iloc[18:36, 15])
mean_iCOH_LP_alpha = statistics.mean(df2.iloc[36:54, 15])
mean_iCOH_LP_gamma = statistics.mean(df2.iloc[54:72, 15])
mean_iCOH_LP = [mean_iCOH_LP_delta, mean_iCOH_LP_theta, mean_iCOH_LP_alpha, mean_iCOH_LP_gamma]

mean_SEiCOH_LP_delta = scipy.stats.sem(df2.iloc[0:18, 15])
mean_SEiCOH_LP_theta = scipy.stats.sem(df2.iloc[18:36, 15])
mean_SEiCOH_LP_alpha = scipy.stats.sem(df2.iloc[36:54, 15])
mean_SEiCOH_LP_gamma = scipy.stats.sem(df2.iloc[54:72, 15])
mean_SEiCOH_LP = [mean_SEiCOH_LP_delta, mean_SEiCOH_LP_theta, mean_SEiCOH_LP_alpha, mean_SEiCOH_LP_gamma]

mean_iCOH_LT_delta = statistics.mean(df2.iloc[72:90, 15])
mean_iCOH_LT_theta = statistics.mean(df2.iloc[90:108, 15])
mean_iCOH_LT_alpha = statistics.mean(df2.iloc[108:126, 15])
mean_iCOH_LT_gamma = statistics.mean(df2.iloc[126:144, 15])
mean_iCOH_LT = [mean_iCOH_LT_delta, mean_iCOH_LT_theta, mean_iCOH_LT_alpha, mean_iCOH_LT_gamma]

mean_SEiCOH_LT_delta = scipy.stats.sem(df2.iloc[72:90, 15])
mean_SEiCOH_LT_theta = scipy.stats.sem(df2.iloc[90:108, 15])
mean_SEiCOH_LT_alpha = scipy.stats.sem(df2.iloc[108:126, 15])
mean_SEiCOH_LT_gamma = scipy.stats.sem(df2.iloc[126:144, 15])
mean_SEiCOH_LT = [mean_SEiCOH_LT_delta, mean_SEiCOH_LT_theta, mean_SEiCOH_LT_alpha, mean_SEiCOH_LT_gamma]

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_PLI_LP_delta = statistics.mean(df2.iloc[0:18, 17])
mean_PLI_LP_theta = statistics.mean(df2.iloc[18:36, 17])
mean_PLI_LP_alpha = statistics.mean(df2.iloc[36:54, 17])
mean_PLI_LP_gamma = statistics.mean(df2.iloc[54:72, 17])
mean_PLI_LP = [mean_PLI_LP_delta, mean_PLI_LP_theta, mean_PLI_LP_alpha, mean_PLI_LP_gamma]

mean_SEPLI_LP_delta = scipy.stats.sem(df2.iloc[0:18, 17])
mean_SEPLI_LP_theta = scipy.stats.sem(df2.iloc[18:36, 17])
mean_SEPLI_LP_alpha = scipy.stats.sem(df2.iloc[36:54, 17])
mean_SEPLI_LP_gamma = scipy.stats.sem(df2.iloc[54:72, 17])
mean_SEPLI_LP = [mean_SEPLI_LP_delta, mean_SEPLI_LP_theta, mean_SEPLI_LP_alpha, mean_SEPLI_LP_gamma]

mean_PLI_LT_delta = statistics.mean(df2.iloc[72:90, 17])
mean_PLI_LT_theta = statistics.mean(df2.iloc[90:108, 17])
mean_PLI_LT_alpha = statistics.mean(df2.iloc[108:126, 17])
mean_PLI_LT_gamma = statistics.mean(df2.iloc[126:144, 17])
mean_PLI_LT = [mean_PLI_LT_delta, mean_PLI_LT_theta, mean_PLI_LT_alpha, mean_PLI_LT_gamma]

mean_SEPLI_LT_delta = scipy.stats.sem(df2.iloc[72:90, 17])
mean_SEPLI_LT_theta = scipy.stats.sem(df2.iloc[90:108, 17])
mean_SEPLI_LT_alpha = scipy.stats.sem(df2.iloc[108:126, 17])
mean_SEPLI_LT_gamma = scipy.stats.sem(df2.iloc[126:144, 17])
mean_SEPLI_LT = [mean_SEPLI_LT_delta, mean_SEPLI_LT_theta, mean_SEPLI_LT_alpha, mean_SEPLI_LT_gamma]

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_wPLI_LP_delta = statistics.mean(df2.iloc[0:18, 19])
mean_wPLI_LP_theta = statistics.mean(df2.iloc[18:36, 19])
mean_wPLI_LP_alpha = statistics.mean(df2.iloc[36:54, 19])
mean_wPLI_LP_gamma = statistics.mean(df2.iloc[54:72, 19])
mean_wPLI_LP = [mean_wPLI_LP_delta, mean_wPLI_LP_theta, mean_wPLI_LP_alpha, mean_wPLI_LP_gamma]

mean_SEwPLI_LP_delta = scipy.stats.sem(df2.iloc[0:18, 19])
mean_SEwPLI_LP_theta = scipy.stats.sem(df2.iloc[18:36, 19])
mean_SEwPLI_LP_alpha = scipy.stats.sem(df2.iloc[36:54, 19])
mean_SEwPLI_LP_gamma = scipy.stats.sem(df2.iloc[54:72, 19])
mean_SEwPLI_LP = [mean_SEwPLI_LP_delta, mean_SEwPLI_LP_theta, mean_SEwPLI_LP_alpha, mean_SEwPLI_LP_gamma]

mean_wPLI_LT_delta = statistics.mean(df2.iloc[72:90, 19])
mean_wPLI_LT_theta = statistics.mean(df2.iloc[90:108, 19])
mean_wPLI_LT_alpha = statistics.mean(df2.iloc[108:126, 19])
mean_wPLI_LT_gamma = statistics.mean(df2.iloc[126:144, 19])
mean_wPLI_LT = [mean_wPLI_LT_delta, mean_wPLI_LT_theta, mean_wPLI_LT_alpha, mean_wPLI_LT_gamma]

mean_SEwPLI_LT_delta = scipy.stats.sem(df2.iloc[72:90, 19])
mean_SEwPLI_LT_theta = scipy.stats.sem(df2.iloc[90:108, 19])
mean_SEwPLI_LT_alpha = scipy.stats.sem(df2.iloc[108:126, 19])
mean_SEwPLI_LT_gamma = scipy.stats.sem(df2.iloc[126:144, 19])
mean_SEwPLI_LT = [mean_SEwPLI_LT_delta, mean_SEwPLI_LT_theta, mean_SEwPLI_LT_alpha, mean_SEwPLI_LT_gamma]

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_DSPLI_LP_delta = statistics.mean(df2.iloc[0:18, 21])
mean_DSPLI_LP_theta = statistics.mean(df2.iloc[18:36, 21])
mean_DSPLI_LP_alpha = statistics.mean(df2.iloc[36:54, 21])
mean_DSPLI_LP_gamma = statistics.mean(df2.iloc[54:72, 21])
mean_DSPLI_LP = [mean_DSPLI_LP_delta, mean_DSPLI_LP_theta, mean_DSPLI_LP_alpha, mean_DSPLI_LP_gamma]

mean_SEDSPLI_LP_delta = scipy.stats.sem(df2.iloc[0:18, 21])
mean_SEDSPLI_LP_theta = scipy.stats.sem(df2.iloc[18:36, 21])
mean_SEDSPLI_LP_alpha = scipy.stats.sem(df2.iloc[36:54, 21])
mean_SEDSPLI_LP_gamma = scipy.stats.sem(df2.iloc[54:72, 21])
mean_SEDSPLI_LP = [mean_SEDSPLI_LP_delta, mean_SEDSPLI_LP_theta, mean_SEDSPLI_LP_alpha, mean_SEDSPLI_LP_gamma]

mean_DSPLI_LT_delta = statistics.mean(df2.iloc[72:90, 21])
mean_DSPLI_LT_theta = statistics.mean(df2.iloc[90:108, 21])
mean_DSPLI_LT_alpha = statistics.mean(df2.iloc[108:126, 21])
mean_DSPLI_LT_gamma = statistics.mean(df2.iloc[126:144, 21])
mean_DSPLI_LT = [mean_DSPLI_LT_delta, mean_DSPLI_LT_theta, mean_DSPLI_LT_alpha, mean_DSPLI_LT_gamma]

mean_SEDSPLI_LT_delta = scipy.stats.sem(df2.iloc[72:90, 21])
mean_SEDSPLI_LT_theta = scipy.stats.sem(df2.iloc[90:108, 21])
mean_SEDSPLI_LT_alpha = scipy.stats.sem(df2.iloc[108:126, 21])
mean_SEDSPLI_LT_gamma = scipy.stats.sem(df2.iloc[126:144, 21])
mean_SEDSPLI_LT = [mean_SEDSPLI_LT_delta, mean_SEDSPLI_LT_theta, mean_SEDSPLI_LT_alpha, mean_SEDSPLI_LT_gamma]

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_wDSPLI_LP_delta = statistics.mean(df2.iloc[0:18, 23])
mean_wDSPLI_LP_theta = statistics.mean(df2.iloc[18:36, 23])
mean_wDSPLI_LP_alpha = statistics.mean(df2.iloc[36:54, 23])
mean_wDSPLI_LP_gamma = statistics.mean(df2.iloc[54:72, 23])
mean_wDSPLI_LP = [mean_wDSPLI_LP_delta, mean_wDSPLI_LP_theta, mean_wDSPLI_LP_alpha, mean_wDSPLI_LP_gamma]

mean_SEwDSPLI_LP_delta = scipy.stats.sem(df2.iloc[0:18, 23])
mean_SEwDSPLI_LP_theta = scipy.stats.sem(df2.iloc[18:36, 23])
mean_SEwDSPLI_LP_alpha = scipy.stats.sem(df2.iloc[36:54, 23])
mean_SEwDSPLI_LP_gamma = scipy.stats.sem(df2.iloc[54:72, 23])
mean_SEwDSPLI_LP = [mean_SEwDSPLI_LP_delta, mean_SEwDSPLI_LP_theta, mean_SEwDSPLI_LP_alpha, mean_SEwDSPLI_LP_gamma]

mean_wDSPLI_LT_delta = statistics.mean(df2.iloc[72:90, 23])
mean_wDSPLI_LT_theta = statistics.mean(df2.iloc[90:108, 23])
mean_wDSPLI_LT_alpha = statistics.mean(df2.iloc[108:126, 23])
mean_wDSPLI_LT_gamma = statistics.mean(df2.iloc[126:144, 23])
mean_wDSPLI_LT = [mean_wDSPLI_LT_delta, mean_wDSPLI_LT_theta, mean_wDSPLI_LT_alpha, mean_wDSPLI_LT_gamma]

mean_SEwDSPLI_LT_delta = scipy.stats.sem(df2.iloc[72:90, 23])
mean_SEwDSPLI_LT_theta = scipy.stats.sem(df2.iloc[90:108, 23])
mean_SEwDSPLI_LT_alpha = scipy.stats.sem(df2.iloc[108:126, 23])
mean_SEwDSPLI_LT_gamma = scipy.stats.sem(df2.iloc[126:144, 23])
mean_SEwDSPLI_LT = [mean_SEwDSPLI_LT_delta, mean_SEwDSPLI_LT_theta, mean_SEwDSPLI_LT_alpha, mean_SEwDSPLI_LT_gamma]

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_PPC_LP_delta = statistics.mean(df2.iloc[0:18, 25])
mean_PPC_LP_theta = statistics.mean(df2.iloc[18:36, 25])
mean_PPC_LP_alpha = statistics.mean(df2.iloc[36:54, 25])
mean_PPC_LP_gamma = statistics.mean(df2.iloc[54:72, 25])
mean_PPC_LP = [mean_PPC_LP_delta, mean_PPC_LP_theta, mean_PPC_LP_alpha, mean_PPC_LP_gamma]

mean_SEPPC_LP_delta = scipy.stats.sem(df2.iloc[0:18, 25])
mean_SEPPC_LP_theta = scipy.stats.sem(df2.iloc[18:36, 25])
mean_SEPPC_LP_alpha = scipy.stats.sem(df2.iloc[36:54, 25])
mean_SEPPC_LP_gamma = scipy.stats.sem(df2.iloc[54:72, 25])
mean_SEPPC_LP = [mean_SEPPC_LP_delta, mean_SEPPC_LP_theta, mean_SEPPC_LP_alpha, mean_SEPPC_LP_gamma]

mean_PPC_LT_delta = statistics.mean(df2.iloc[72:90, 25])
mean_PPC_LT_theta = statistics.mean(df2.iloc[90:108, 25])
mean_PPC_LT_alpha = statistics.mean(df2.iloc[108:126, 25])
mean_PPC_LT_gamma = statistics.mean(df2.iloc[126:144, 25])
mean_PPC_LT = [mean_PPC_LT_delta, mean_PPC_LT_theta, mean_PPC_LT_alpha, mean_PPC_LT_gamma]

mean_SEPPC_LT_delta = scipy.stats.sem(df2.iloc[72:90, 25])
mean_SEPPC_LT_theta = scipy.stats.sem(df2.iloc[90:108, 25])
mean_SEPPC_LT_alpha = scipy.stats.sem(df2.iloc[108:126, 25])
mean_SEPPC_LT_gamma = scipy.stats.sem(df2.iloc[126:144, 25])
mean_SEPPC_LT = [mean_SEPPC_LT_delta, mean_SEPPC_LT_theta, mean_SEPPC_LT_alpha, mean_SEPPC_LT_gamma]

# %%
#Learning vs home cage:
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(15, 20), constrained_layout=True)
axes[0,0].scatter(frequency_LP, COH_LP, label='phasic learning')
axes[0,0].errorbar(frequencies, mean_COH_LP, mean_SECOH_LP, fmt="v", color = 'black', label='mean learning')
axes[0,0].scatter(frequency_LT, COH_LT, label='tonic learning')
axes[0,0].errorbar(frequencies, mean_COH_LT, mean_SECOH_LT, fmt="v", color = 'black', label='mean learning')

axes[0,0].scatter(frequency_phc, COH_phc, label='phasic HC')
axes[0,0].errorbar(frequencies, mean_COH_phc, mean_SECOH_phc, fmt="v", color = 'yellow', label='mean HC')
axes[0,0].scatter(frequency_thc, COH_thc, label='tonic HC')
axes[0,0].errorbar(frequencies, mean_COH_thc, mean_SECOH_thc, fmt="v", color = 'yellow', label='mean HC')
axes[0,0].legend()
axes[0,0].set_xlabel('frequency bin')
axes[0,0].set_ylabel('COH')

axes[0,1].scatter(frequency_LP, iCOH_LP, label='phasic learning')
axes[0,1].errorbar(frequencies, mean_iCOH_LP, mean_SEiCOH_LP, fmt="v", color = 'black', label='mean learning')
axes[0,1].scatter(frequency_LT, iCOH_LT, label='tonic learning')
axes[0,1].errorbar(frequencies, mean_iCOH_LT, mean_SEiCOH_LT, fmt="v", color = 'black', label='mean learning')

axes[0,1].scatter(frequency_phc, iCOH_phc, label='phasic HC')
axes[0,1].errorbar(frequencies, mean_iCOH_phc, mean_SEiCOH_phc, fmt="v", color = 'yellow', label='mean HC')
axes[0,1].scatter(frequency_thc, iCOH_thc, label='tonic HC')
axes[0,1].errorbar(frequencies, mean_iCOH_thc, mean_SEiCOH_thc, fmt="v", color = 'yellow', label='mean HC')
axes[0,1].legend()
axes[0,1].set_xlabel('frequency bin')
axes[0,1].set_ylabel('iCOH')

axes[1,0].scatter(frequency_LP, PLI_LP, label='phasic learning')
axes[1,0].errorbar(frequencies, mean_PLI_LP, mean_SEPLI_LP, fmt="v", color = 'black', label='mean learning')
axes[1,0].scatter(frequency_LT, PLI_LT, label='tonic learning')
axes[1,0].errorbar(frequencies, mean_PLI_LT, mean_SEPLI_LT, fmt="v", color = 'black', label='mean learning')

axes[1,0].scatter(frequency_phc, PLI_phc, label='phasic HC')
axes[1,0].errorbar(frequencies, mean_PLI_phc, mean_SEPLI_phc, fmt="v", color = 'yellow', label='mean HC')
axes[1,0].scatter(frequency_thc, PLI_thc, label='tonic HC')
axes[1,0].errorbar(frequencies, mean_PLI_thc, mean_SEPLI_thc, fmt="v", color = 'yellow', label='mean HC')
axes[1,0].legend()
axes[1,0].set_xlabel('frequency bin')
axes[1,0].set_ylabel('PLI')
                  
axes[1,1].scatter(frequency_LP, wPLI_LP, label='phasic learning')
axes[1,1].errorbar(frequencies, mean_wPLI_LP, mean_SEwPLI_LP, fmt="v", color = 'black', label='mean learning')
axes[1,1].scatter(frequency_LT, wPLI_LT, label='tonic learning')
axes[1,1].errorbar(frequencies, mean_wPLI_LT, mean_SEwPLI_LT, fmt="v", color = 'black', label='mean learning')

axes[1,1].scatter(frequency_phc, wPLI_phc, label='phasic HC')
axes[1,1].errorbar(frequencies, mean_wPLI_phc, mean_SEwPLI_phc, fmt="v", color = 'yellow', label='mean HC')
axes[1,1].scatter(frequency_thc, wPLI_thc, label='tonic HC')
axes[1,1].errorbar(frequencies, mean_wPLI_thc, mean_SEwPLI_thc, fmt="v", color = 'yellow', label='mean HC')
axes[1,1].legend()
axes[1,1].set_xlabel('frequency bin')
axes[1,1].set_ylabel('wPLI') 

axes[2,0].scatter(frequency_LP, DSPLI_LP, label='phasic learning')
axes[2,0].errorbar(frequencies, mean_DSPLI_LP, mean_SEDSPLI_LP, fmt="v", color = 'black', label='mean learning')
axes[2,0].scatter(frequency_LT, DSPLI_LT, label='tonic learning')
axes[2,0].errorbar(frequencies, mean_DSPLI_LT, mean_SEDSPLI_LT, fmt="v", color = 'black', label='mean learning')

axes[2,0].scatter(frequency_phc, DSPLI_phc, label='phasic HC')
axes[2,0].errorbar(frequencies, mean_DSPLI_phc, mean_SEDSPLI_phc, fmt="v", color = 'yellow', label='mean HC')
axes[2,0].scatter(frequency_thc, DSPLI_thc, label='tonic HC')
axes[2,0].errorbar(frequencies, mean_DSPLI_thc, mean_SEDSPLI_thc, fmt="v", color = 'yellow', label='mean HC')
axes[2,0].legend()
axes[2,0].set_xlabel('frequency bin')
axes[2,0].set_ylabel('DSPLI')
                  
axes[2,1].scatter(frequency_LP, wDSPLI_LP, label='phasic learning')
axes[2,1].errorbar(frequencies, mean_wDSPLI_LP, mean_SEwDSPLI_LP, fmt="v", color = 'black', label='mean learning')
axes[2,1].scatter(frequency_LT, wDSPLI_LT, label='tonic learning')
axes[2,1].errorbar(frequencies, mean_wDSPLI_LT, mean_SEwDSPLI_LT, fmt="v", color = 'black', label='mean learning')

axes[2,1].scatter(frequency_phc, wDSPLI_phc, label='phasic HC')
axes[2,1].errorbar(frequencies, mean_wDSPLI_phc, mean_SEwDSPLI_phc, fmt="v", color = 'yellow', label='mean HC')
axes[2,1].scatter(frequency_thc, wDSPLI_thc, label='tonic HC')
axes[2,1].errorbar(frequencies, mean_wDSPLI_thc, mean_SEwDSPLI_thc, fmt="v", color = 'purple', label='mean HC')
axes[2,1].legend()
axes[2,1].set_xlabel('frequency bin')
axes[2,1].set_ylabel('wDSPLI')

axes[3,0].scatter(frequency_LP, PPC_LP, label='phasic learning')
axes[3,0].errorbar(frequencies, mean_PPC_LP, mean_SEPPC_LP, fmt="v", color = 'black', label='mean learning')
axes[3,0].scatter(frequency_LT, PPC_LT, label='tonic learning')
axes[3,0].errorbar(frequencies, mean_PPC_LT, mean_SEPPC_LT, fmt="v", color = 'black', label='mean learning')

axes[3,0].scatter(frequency_phc, PPC_phc, label='phasic HC')
axes[3,0].errorbar(frequencies, mean_PPC_phc, mean_SEPPC_phc, fmt="v", color = 'yellow', label='mean HC')
axes[3,0].scatter(frequency_thc, PPC_thc, label='tonic HC')
axes[3,0].errorbar(frequencies, mean_PPC_thc, mean_SEPPC_thc, fmt="v", color = 'yellow', label='mean HC')
axes[3,0].legend()
axes[3,0].set_xlabel('frequency bin')
axes[3,0].set_ylabel('PPC')
# Out:
# Text(0, 0.5, 'PPC')

# %% [markdown]
# ## All

# %%
df3 = pd.read_excel('all_results_table_ALL.xlsx')
print(df3)
# Out:
#                          Name  Data set  RatID  StudyDay Condition  Treatment  \
# 0    Rat1_SD1_CN_4_posttrial2  OS_Basic      1         1        CN          4
# 1    Rat1_SD1_CN_4_posttrial4  OS_Basic      1         1        CN          4
# 2    Rat3_SD1_CN_4_posttrial4  OS_Basic      3         1        CN          4
# 3    Rat3_SD1_CN_4_posttrial5  OS_Basic      3         1        CN          4
# 4    Rat4_SD1_CN_4_posttrial2  OS_Basic      4         1        CN          4
# ..                        ...       ...    ...       ...       ...        ...
# 183  Rat1_SD2_OR_4_posttrial4  OS_Basic      1         2        OR          4
# 184  Rat3_SD1_OR_4_posttrial4  OS_Basic      3         1        OR          4
# 185  Rat3_SD1_OR_4_posttrial5  OS_Basic      3         1        OR          4
# 186  Rat4_SD3_OR_4_posttrial4  OS_Basic      4         3        OR          4
# 187  Rat4_SD3_OR_4_posttrial5  OS_Basic      4         3        OR          4
#
# ...

# %%
frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_COH_ALLP_delta = statistics.mean(df3.iloc[0:23, 13])
mean_COH_ALLP_theta = statistics.mean(df3.iloc[23:46, 13])
mean_COH_ALLP_alpha = statistics.mean(df3.iloc[46:69, 13])
mean_COH_ALLP_gamma = statistics.mean(df3.iloc[69:92, 13])
mean_COH_ALLP = [mean_COH_ALLP_delta, mean_COH_ALLP_theta, mean_COH_ALLP_alpha, mean_COH_ALLP_gamma]

mean_SECOH_ALLP_delta = scipy.stats.sem(df3.iloc[0:23, 13])
mean_SECOH_ALLP_theta = scipy.stats.sem(df3.iloc[23:46, 13])
mean_SECOH_ALLP_alpha = scipy.stats.sem(df3.iloc[46:69, 13])
mean_SECOH_ALLP_gamma = scipy.stats.sem(df3.iloc[69:92, 13])
mean_SECOH_ALLP = [mean_SECOH_ALLP_delta, mean_SECOH_ALLP_theta, mean_SECOH_ALLP_alpha, mean_SECOH_ALLP_gamma]

mean_COH_ALLT_delta = statistics.mean(df3.iloc[92:116, 13])
mean_COH_ALLT_theta = statistics.mean(df3.iloc[116:140, 13])
mean_COH_ALLT_alpha = statistics.mean(df3.iloc[140:164, 13])
mean_COH_ALLT_gamma = statistics.mean(df3.iloc[164:188, 13])
mean_COH_ALLT = [mean_COH_ALLT_delta, mean_COH_ALLT_theta, mean_COH_ALLT_alpha, mean_COH_ALLT_gamma]

mean_SECOH_ALLT_delta = scipy.stats.sem(df3.iloc[92:116, 13])
mean_SECOH_ALLT_theta = scipy.stats.sem(df3.iloc[116:140, 13])
mean_SECOH_ALLT_alpha = scipy.stats.sem(df3.iloc[140:164, 13])
mean_SECOH_ALLT_gamma = scipy.stats.sem(df3.iloc[164:188, 13])
mean_SECOH_ALLT = [mean_SECOH_ALLT_delta, mean_SECOH_ALLT_theta, mean_SECOH_ALLT_alpha, mean_SECOH_ALLT_gamma]


frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_iCOH_ALLP_delta = statistics.mean(df3.iloc[0:23, 15])
mean_iCOH_ALLP_theta = statistics.mean(df3.iloc[23:46, 15])
mean_iCOH_ALLP_alpha = statistics.mean(df3.iloc[46:69, 15])
mean_iCOH_ALLP_gamma = statistics.mean(df3.iloc[69:92, 15])
mean_iCOH_ALLP = [mean_iCOH_ALLP_delta, mean_iCOH_ALLP_theta, mean_iCOH_ALLP_alpha, mean_iCOH_ALLP_gamma]

mean_SEiCOH_ALLP_delta = scipy.stats.sem(df3.iloc[0:23, 15])
mean_SEiCOH_ALLP_theta = scipy.stats.sem(df3.iloc[23:46, 15])
mean_SEiCOH_ALLP_alpha = scipy.stats.sem(df3.iloc[46:69, 15])
mean_SEiCOH_ALLP_gamma = scipy.stats.sem(df3.iloc[69:92, 15])
mean_SEiCOH_ALLP = [mean_SEiCOH_ALLP_delta, mean_SEiCOH_ALLP_theta, mean_SEiCOH_ALLP_alpha, mean_SEiCOH_ALLP_gamma]

mean_iCOH_ALLT_delta = statistics.mean(df3.iloc[92:116, 15])
mean_iCOH_ALLT_theta = statistics.mean(df3.iloc[116:140, 15])
mean_iCOH_ALLT_alpha = statistics.mean(df3.iloc[140:164, 15])
mean_iCOH_ALLT_gamma = statistics.mean(df3.iloc[164:188, 15])
mean_iCOH_ALLT = [mean_iCOH_ALLT_delta, mean_iCOH_ALLT_theta, mean_iCOH_ALLT_alpha, mean_iCOH_ALLT_gamma]

mean_SEiCOH_ALLT_delta = scipy.stats.sem(df3.iloc[92:116, 15])
mean_SEiCOH_ALLT_theta = scipy.stats.sem(df3.iloc[116:140, 15])
mean_SEiCOH_ALLT_alpha = scipy.stats.sem(df3.iloc[140:164, 15])
mean_SEiCOH_ALLT_gamma = scipy.stats.sem(df3.iloc[164:188, 15])
mean_SEiCOH_ALLT = [mean_SEiCOH_ALLT_delta, mean_SEiCOH_ALLT_theta, mean_SEiCOH_ALLT_alpha, mean_SEiCOH_ALLT_gamma]


frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_PLI_ALLP_delta = statistics.mean(df3.iloc[0:23, 17])
mean_PLI_ALLP_theta = statistics.mean(df3.iloc[23:46, 17])
mean_PLI_ALLP_alpha = statistics.mean(df2.iloc[46:69, 17])
mean_PLI_ALLP_gamma = statistics.mean(df2.iloc[69:92, 17])
mean_PLI_ALLP = [mean_PLI_ALLP_delta, mean_PLI_ALLP_theta, mean_PLI_ALLP_alpha, mean_PLI_ALLP_gamma]

mean_SEPLI_ALLP_delta = scipy.stats.sem(df3.iloc[0:23, 17])
mean_SEPLI_ALLP_theta = scipy.stats.sem(df3.iloc[23:46, 17])
mean_SEPLI_ALLP_alpha = scipy.stats.sem(df3.iloc[46:69, 17])
mean_SEPLI_ALLP_gamma = scipy.stats.sem(df3.iloc[69:92, 17])
mean_SEPLI_ALLP = [mean_SEPLI_ALLP_delta, mean_SEPLI_ALLP_theta, mean_SEPLI_ALLP_alpha, mean_SEPLI_ALLP_gamma]

mean_PLI_ALLT_delta = statistics.mean(df3.iloc[92:116, 17])
mean_PLI_ALLT_theta = statistics.mean(df3.iloc[116:140, 17])
mean_PLI_ALLT_alpha = statistics.mean(df3.iloc[140:164, 17])
mean_PLI_ALLT_gamma = statistics.mean(df3.iloc[164:188, 17])
mean_PLI_ALLT = [mean_PLI_ALLT_delta, mean_PLI_ALLT_theta, mean_PLI_ALLT_alpha, mean_PLI_ALLT_gamma]

mean_SEPLI_ALLT_delta = scipy.stats.sem(df3.iloc[92:116, 17])
mean_SEPLI_ALLT_theta = scipy.stats.sem(df3.iloc[116:140, 17])
mean_SEPLI_ALLT_alpha = scipy.stats.sem(df3.iloc[140:164, 17])
mean_SEPLI_ALLT_gamma = scipy.stats.sem(df3.iloc[164:188, 17])
mean_SEPLI_ALLT = [mean_SEPLI_ALLT_delta, mean_SEPLI_ALLT_theta, mean_SEPLI_ALLT_alpha, mean_SEPLI_ALLT_gamma]


frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_wPLI_ALLP_delta = statistics.mean(df3.iloc[0:23, 19])
mean_wPLI_ALLP_theta = statistics.mean(df3.iloc[23:46, 19])
mean_wPLI_ALLP_alpha = statistics.mean(df3.iloc[46:69, 19])
mean_wPLI_ALLP_gamma = statistics.mean(df3.iloc[69:92, 19])
mean_wPLI_ALLP = [mean_wPLI_ALLP_delta, mean_wPLI_ALLP_theta, mean_wPLI_ALLP_alpha, mean_wPLI_ALLP_gamma]

mean_SEwPLI_ALLP_delta = scipy.stats.sem(df3.iloc[0:23, 19])
mean_SEwPLI_ALLP_theta = scipy.stats.sem(df3.iloc[23:46, 19])
mean_SEwPLI_ALLP_alpha = scipy.stats.sem(df3.iloc[46:69, 19])
mean_SEwPLI_ALLP_gamma = scipy.stats.sem(df3.iloc[69:92, 19])
mean_SEwPLI_ALLP = [mean_SEwPLI_ALLP_delta, mean_SEwPLI_ALLP_theta, mean_SEwPLI_ALLP_alpha, mean_SEwPLI_ALLP_gamma]

mean_wPLI_ALLT_delta = statistics.mean(df3.iloc[92:116, 19])
mean_wPLI_ALLT_theta = statistics.mean(df3.iloc[116:140, 19])
mean_wPLI_ALLT_alpha = statistics.mean(df3.iloc[140:164, 19])
mean_wPLI_ALLT_gamma = statistics.mean(df3.iloc[164:188, 19])
mean_wPLI_ALLT = [mean_wPLI_ALLT_delta, mean_wPLI_ALLT_theta, mean_wPLI_ALLT_alpha, mean_wPLI_ALLT_gamma]

mean_SEwPLI_ALLT_delta = scipy.stats.sem(df3.iloc[92:116, 19])
mean_SEwPLI_ALLT_theta = scipy.stats.sem(df3.iloc[116:140, 19])
mean_SEwPLI_ALLT_alpha = scipy.stats.sem(df3.iloc[140:164, 19])
mean_SEwPLI_ALLT_gamma = scipy.stats.sem(df3.iloc[164:188, 19])
mean_SEwPLI_ALLT = [mean_SEwPLI_ALLT_delta, mean_SEwPLI_ALLT_theta, mean_SEwPLI_ALLT_alpha, mean_SEwPLI_ALLT_gamma]


frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_DSPLI_ALLP_delta = statistics.mean(df3.iloc[0:23, 21])
mean_DSPLI_ALLP_theta = statistics.mean(df3.iloc[23:46, 21])
mean_DSPLI_ALLP_alpha = statistics.mean(df3.iloc[46:69, 21])
mean_DSPLI_ALLP_gamma = statistics.mean(df3.iloc[69:92, 21])
mean_DSPLI_ALLP = [mean_DSPLI_ALLP_delta, mean_DSPLI_ALLP_theta, mean_DSPLI_ALLP_alpha, mean_DSPLI_ALLP_gamma]

mean_SEDSPLI_ALLP_delta = scipy.stats.sem(df3.iloc[0:23, 21])
mean_SEDSPLI_ALLP_theta = scipy.stats.sem(df3.iloc[23:46, 21])
mean_SEDSPLI_ALLP_alpha = scipy.stats.sem(df3.iloc[46:69, 21])
mean_SEDSPLI_ALLP_gamma = scipy.stats.sem(df3.iloc[69:92, 21])
mean_SEDSPLI_ALLP = [mean_SEDSPLI_ALLP_delta, mean_SEDSPLI_ALLP_theta, mean_SEDSPLI_ALLP_alpha, mean_SEDSPLI_ALLP_gamma]

mean_DSPLI_ALLT_delta = statistics.mean(df3.iloc[92:116, 21])
mean_DSPLI_ALLT_theta = statistics.mean(df3.iloc[116:140, 21])
mean_DSPLI_ALLT_alpha = statistics.mean(df3.iloc[140:164, 21])
mean_DSPLI_ALLT_gamma = statistics.mean(df3.iloc[164:188, 21])
mean_DSPLI_ALLT = [mean_DSPLI_ALLT_delta, mean_DSPLI_ALLT_theta, mean_DSPLI_ALLT_alpha, mean_DSPLI_ALLT_gamma]

mean_SEDSPLI_ALLT_delta = scipy.stats.sem(df3.iloc[92:116, 21])
mean_SEDSPLI_ALLT_theta = scipy.stats.sem(df3.iloc[116:140, 21])
mean_SEDSPLI_ALLT_alpha = scipy.stats.sem(df3.iloc[140:164, 21])
mean_SEDSPLI_ALLT_gamma = scipy.stats.sem(df3.iloc[164:188, 21])
mean_SEDSPLI_ALLT = [mean_SEDSPLI_ALLT_delta, mean_SEDSPLI_ALLT_theta, mean_SEDSPLI_ALLT_alpha, mean_SEDSPLI_ALLT_gamma]


frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_wDSPLI_ALLP_delta = statistics.mean(df3.iloc[0:23, 23])
mean_wDSPLI_ALLP_theta = statistics.mean(df3.iloc[23:46, 23])
mean_wDSPLI_ALLP_alpha = statistics.mean(df3.iloc[46:69, 23])
mean_wDSPLI_ALLP_gamma = statistics.mean(df3.iloc[69:92, 23])
mean_wDSPLI_ALLP = [mean_wDSPLI_ALLP_delta, mean_wDSPLI_ALLP_theta, mean_wDSPLI_ALLP_alpha, mean_wDSPLI_ALLP_gamma]

mean_SEwDSPLI_ALLP_delta = scipy.stats.sem(df3.iloc[0:23, 23])
mean_SEwDSPLI_ALLP_theta = scipy.stats.sem(df3.iloc[23:46, 23])
mean_SEwDSPLI_ALLP_alpha = scipy.stats.sem(df3.iloc[46:69, 23])
mean_SEwDSPLI_ALLP_gamma = scipy.stats.sem(df3.iloc[69:92, 23])
mean_SEwDSPLI_ALLP = [mean_SEwDSPLI_ALLP_delta, mean_SEwDSPLI_ALLP_theta, mean_SEwDSPLI_ALLP_alpha, mean_SEwDSPLI_ALLP_gamma]

mean_wDSPLI_ALLT_delta = statistics.mean(df3.iloc[92:116, 23])
mean_wDSPLI_ALLT_theta = statistics.mean(df3.iloc[116:140, 23])
mean_wDSPLI_ALLT_alpha = statistics.mean(df3.iloc[140:164, 23])
mean_wDSPLI_ALLT_gamma = statistics.mean(df3.iloc[164:188, 23])
mean_wDSPLI_ALLT = [mean_wDSPLI_ALLT_delta, mean_wDSPLI_ALLT_theta, mean_wDSPLI_ALLT_alpha, mean_wDSPLI_ALLT_gamma]

mean_SEwDSPLI_ALLT_delta = scipy.stats.sem(df3.iloc[92:116, 23])
mean_SEwDSPLI_ALLT_theta = scipy.stats.sem(df3.iloc[116:140, 23])
mean_SEwDSPLI_ALLT_alpha = scipy.stats.sem(df3.iloc[140:164, 23])
mean_SEwDSPLI_ALLT_gamma = scipy.stats.sem(df3.iloc[164:188, 23])
mean_SEwDSPLI_ALLT = [mean_SEwDSPLI_ALLT_delta, mean_SEwDSPLI_ALLT_theta, mean_SEwDSPLI_ALLT_alpha, mean_SEwDSPLI_ALLT_gamma]


frequencies = ['delta (1-4 Hz)', 'theta (5-12 Hz)', 'alpha/beta (13-20 Hz)', 'gamma (20-140 Hz)']
mean_PPC_ALLP_delta = statistics.mean(df3.iloc[0:23, 25])
mean_PPC_ALLP_theta = statistics.mean(df3.iloc[23:46, 25])
mean_PPC_ALLP_alpha = statistics.mean(df3.iloc[46:69, 25])
mean_PPC_ALLP_gamma = statistics.mean(df3.iloc[69:92, 25])
mean_PPC_ALLP = [mean_PPC_ALLP_delta, mean_PPC_ALLP_theta, mean_PPC_ALLP_alpha, mean_PPC_ALLP_gamma]

mean_SEPPC_ALLP_delta = scipy.stats.sem(df3.iloc[0:23, 25])
mean_SEPPC_ALLP_theta = scipy.stats.sem(df3.iloc[23:46, 25])
mean_SEPPC_ALLP_alpha = scipy.stats.sem(df3.iloc[46:69, 25])
mean_SEPPC_ALLP_gamma = scipy.stats.sem(df3.iloc[69:92, 25])
mean_SEPPC_ALLP = [mean_SEPPC_ALLP_delta, mean_SEPPC_ALLP_theta, mean_SEPPC_ALLP_alpha, mean_SEPPC_ALLP_gamma]

mean_PPC_ALLT_delta = statistics.mean(df3.iloc[92:116, 25])
mean_PPC_ALLT_theta = statistics.mean(df3.iloc[116:140, 25])
mean_PPC_ALLT_alpha = statistics.mean(df3.iloc[140:164, 25])
mean_PPC_ALLT_gamma = statistics.mean(df3.iloc[164:188, 25])
mean_PPC_ALLT = [mean_PPC_ALLT_delta, mean_PPC_ALLT_theta, mean_PPC_ALLT_alpha, mean_PPC_ALLT_gamma]

mean_SEPPC_ALLT_delta = scipy.stats.sem(df3.iloc[92:116, 25])
mean_SEPPC_ALLT_theta = scipy.stats.sem(df3.iloc[116:140, 25])
mean_SEPPC_ALLT_alpha = scipy.stats.sem(df3.iloc[140:164, 25])
mean_SEPPC_ALLT_gamma = scipy.stats.sem(df3.iloc[164:188, 25])
mean_SEPPC_ALLT = [mean_SEPPC_ALLT_delta, mean_SEPPC_ALLT_theta, mean_SEPPC_ALLT_alpha, mean_SEPPC_ALLT_gamma]

# %%
#ALL:
#Learning vs home cage:
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(15, 20), constrained_layout=True)
axes[0,0].scatter(frequency_ALLP, COH_ALLP, label='phasic')
axes[0,0].errorbar(frequencies, mean_COH_ALLP, mean_SECOH_ALLP, fmt="v", color = 'black', label='mean')
axes[0,0].scatter(frequency_ALLT, COH_ALLT, label='tonic')
axes[0,0].errorbar(frequencies, mean_COH_ALLT, mean_SECOH_ALLT, fmt="v", color = 'black')
axes[0,0].legend()
axes[0,0].set_xlabel('frequency bin')
axes[0,0].set_ylabel('COH')

axes[0,1].scatter(frequency_ALLP, iCOH_ALLP, label='phasic')
axes[0,1].errorbar(frequencies, mean_iCOH_ALLP, mean_SEiCOH_ALLP, fmt="v", color = 'black', label='mean')
axes[0,1].scatter(frequency_ALLT, iCOH_ALLT, label='tonic')
axes[0,1].errorbar(frequencies, mean_iCOH_ALLT, mean_SEiCOH_ALLT, fmt="v", color = 'black')
axes[0,1].legend()
axes[0,1].set_xlabel('frequency bin')
axes[0,1].set_ylabel('iCOH')

axes[1,0].scatter(frequency_ALLP, PLI_ALLP, label='phasic')
axes[1,0].errorbar(frequencies, mean_PLI_ALLP, mean_SEPLI_ALLP, fmt="v", color = 'red', label='mean phasic')
axes[1,0].scatter(frequency_ALLT, PLI_ALLT, label='tonic')
axes[1,0].errorbar(frequencies, mean_PLI_ALLT, mean_SEPLI_ALLT, fmt="v", color = 'black', label='mean tonic')
axes[1,0].legend()
axes[1,0].set_xlabel('frequency bin')
axes[1,0].set_ylabel('PLI')
                  
axes[1,1].scatter(frequency_ALLP, wPLI_ALLP, label='phasic')
axes[1,1].errorbar(frequencies, mean_wPLI_ALLP, mean_SEwPLI_ALLP, fmt="v", color = 'red', label='mean phasic')
axes[1,1].scatter(frequency_ALLT, wPLI_ALLT, label='tonic')
axes[1,1].errorbar(frequencies, mean_wPLI_ALLP, mean_SEwPLI_ALLP, fmt="v", color = 'black', label='mean tonic')
axes[1,1].legend()
axes[1,1].set_xlabel('frequency bin')
axes[1,1].set_ylabel('wPLI') 

axes[2,0].scatter(frequency_ALLP, DSPLI_ALLP, label='phasic')
axes[2,0].errorbar(frequencies, mean_DSPLI_ALLP, mean_SEDSPLI_ALLP, fmt="v", color = 'black', label='mean')
axes[2,0].scatter(frequency_ALLT, DSPLI_ALLT, label='tonic')
axes[2,0].errorbar(frequencies, mean_DSPLI_ALLT, mean_SEDSPLI_ALLT, fmt="v", color = 'black')
axes[2,0].legend()
axes[2,0].set_xlabel('frequency bin')
axes[2,0].set_ylabel('DSPLI')
                  
axes[2,1].scatter(frequency_ALLP, wDSPLI_ALLP, label='phasic')
axes[2,1].errorbar(frequencies, mean_wDSPLI_ALLP, mean_SEwDSPLI_ALLP, fmt="v", color = 'black', label='mean')
axes[2,1].scatter(frequency_ALLT, wDSPLI_ALLT, label='tonic')
axes[2,1].errorbar(frequencies, mean_wDSPLI_ALLT, mean_SEwDSPLI_ALLT, fmt="v", color = 'black')
axes[2,1].legend()
axes[2,1].set_xlabel('frequency bin')
axes[2,1].set_ylabel('wDSPLI')

axes[3,0].scatter(frequency_ALLP, PPC_ALLP, label='phasic')
axes[3,0].errorbar(frequencies, mean_PPC_ALLP, mean_SEPPC_ALLP, fmt="v", color = 'black', label='mean')
axes[3,0].scatter(frequency_ALLT, PPC_ALLT, label='tonic')
axes[3,0].errorbar(frequencies, mean_PPC_ALLT, mean_SEPPC_ALLT, fmt="v", color = 'black')
axes[3,0].legend()
axes[3,0].set_xlabel('frequency bin')
axes[3,0].set_ylabel('PPC')
# Out:
# Text(0, 0.5, 'PPC')

# %%
rows = []
for i in range(4):
    rows.append({
                    ' mean COH pcn': mean_COH_pcn[i],
                    'SE COH pcn': mean_SECOH_pcn[i],
                    ' mean COH tcn': mean_COH_tcn[i],
                    'SE COH tcn': mean_SECOH_tcn[i],
                    'mean iCOH pcn': mean_iCOH_pcn[i],
                    'SE iCOH pcn': mean_SEiCOH_pcn[i],
                    'mean iCOH tcn': mean_iCOH_tcn[i],
                    'SE iCOH tcn': mean_SEiCOH_tcn[i],
                    'mean PLI pcn': mean_PLI_pcn[i],
                    'SE PLI pcn': mean_SEPLI_pcn[i],
                    'mean PLI tcn': mean_PLI_tcn[i],
                    'SE PLI tcn': mean_SEPLI_pcn[i],
                    'mean wPLI pcn': mean_wPLI_pcn[i],
                    'SE wPLI pcn': mean_SEwPLI_pcn[i],
                    'mean wPLI tcn': mean_wPLI_tcn[i],
                    'SE wPLI tcn': mean_SEwPLI_tcn[i],
                    'mean DSPLI pcn': mean_DSPLI_pcn[i],
                    'SE DSPLI pcn': mean_SEDSPLI_pcn[i],
                    'mean DSPLI tcn': mean_DSPLI_pcn[i],
                    'SE DSPLI tcn': mean_SEDSPLI_tcn[i],
                    'mean wDSPLI pcn': mean_wDSPLI_pcn[i],
                    'SE wDSPLI pcn': mean_SEwDSPLI_pcn[i],
                    'mean wDSPLI tcn': mean_wDSPLI_tcn[i],
                    'SE wDSPLI tcn': mean_SEwDSPLI_tcn[i],
                    'mean PPC pcn': mean_PPC_pcn[i],
                    'SE PPC pcn': mean_SEPPC_pcn[i],
                    'mean PPC tcn': mean_PPC_tcn[i],
                    'SE PPC tcn': mean_SEPPC_tcn[i],
    
                    ' mean COH phc': mean_COH_phc[i],
                    'SE COH phc': mean_SECOH_phc[i],
                    ' mean COH thc': mean_COH_thc[i],
                    'SE COH thc': mean_SECOH_thc[i],
                    'mean iCOH phc': mean_iCOH_phc[i],
                    'SE iCOH phc': mean_SEiCOH_phc[i],
                    'mean iCOH thc': mean_iCOH_thc[i],
                    'SE iCOH thc': mean_SEiCOH_thc[i],  
                    'mean PLI phc': mean_PLI_phc[i],
                    'SE PLI phc': mean_SEPLI_phc[i],
                    'mean PLI thc': mean_PLI_thc[i],
                    'SE PLI thc': mean_SEPLI_thc[i],
                    'mean wPLI phc': mean_wPLI_phc[i],
                    'SE wPLI phc': mean_SEwPLI_phc[i],
                    'mean wPLI thc': mean_wPLI_thc[i],
                    'SE wPLI thc': mean_SEwPLI_thc[i],
                    'mean DSPLI phc': mean_DSPLI_phc[i],
                    'SE DSPLI phc': mean_SEDSPLI_phc[i],
                    'mean DSPLI thc': mean_DSPLI_thc[i],
                    'SE DSPLI thc': mean_SEDSPLI_thc[i],
                    'mean wDSPLI phc': mean_wDSPLI_phc[i],
                    'SE wDSPLI phc': mean_SEwDSPLI_phc[i],
                    'mean wDSPLI thc': mean_wDSPLI_thc[i],
                    'SE wDSPLI thc': mean_SEwDSPLI_thc[i],
                    'mean PPC phc': mean_PPC_phc[i],
                    'SE PPC phc': mean_SEPPC_phc[i],
                    'mean PPC thc': mean_PPC_thc[i],
                    'SE PPC thc': mean_SEPPC_thc[i],

                    ' mean COH pod': mean_COH_pod[i],
                    'SE COH pod': mean_SECOH_pod[i],
                    ' mean COH tod': mean_COH_tod[i],
                    'SE COH tod': mean_SECOH_tod[i],
                    'mean iCOH pod': mean_iCOH_pod[i],
                    'SE iCOH pod': mean_SEiCOH_pod[i],
                    'mean iCOH tod': mean_iCOH_tod[i],
                    'SE iCOH tod': mean_SEiCOH_tod[i],
                    'mean PLI pod': mean_PLI_pod[i],
                    'SE PLI pod': mean_SEPLI_pod[i],
                    'mean PLI tod': mean_PLI_tod[i],
                    'SE PLI tod': mean_SEPLI_tod[i],
                    'mean wPLI pod': mean_wPLI_pod[i],
                    'SE wPLI pod': mean_SEwPLI_pod[i],
                    'mean wPLI tod': mean_wPLI_tod[i],
                    'SE wPLI tod': mean_SEwPLI_tod[i],
                    'mean DSPLI pod': mean_DSPLI_pod[i],
                    'SE DSPLI pod': mean_SEDSPLI_pod[i],
                    'mean DSPLI tod': mean_DSPLI_tod[i],
                    'SE DSPLI tod': mean_SEDSPLI_tod[i],
                    'mean wDSPLI pod': mean_wDSPLI_pod[i],
                    'SE wDSPLI pod': mean_SEwDSPLI_pod[i],
                    'mean wDSPLI tod': mean_wDSPLI_tod[i],
                    'SE wDSPLI tod': mean_SEwDSPLI_tod[i],
                    'mean PPC pod': mean_PPC_pod[i],
                    'SE PPC pod': mean_SEPPC_pod[i],
                    'mean PPC tod': mean_PPC_tod[i],
                    'SE PPC tod': mean_SEPPC_tod[i],

                    ' mean COH por': mean_COH_por[i],
                    'SE COH por': mean_SECOH_por[i],
                    ' mean COH tor': mean_COH_tor[i],
                    'SE COH tor': mean_SECOH_tor[i],
                    'mean iCOH por': mean_iCOH_por[i],
                    'SE iCOH por': mean_SEiCOH_por[i],
                    'mean iCOH tor': mean_iCOH_tor[i],
                    'SE iCOH tor': mean_SEiCOH_tor[i],
                    'mean PLI por': mean_PLI_por[i],
                    'SE PLI por': mean_SEPLI_por[i],
                    'mean PLI tor': mean_PLI_tor[i],
                    'SE PLI tor': mean_SEPLI_tor[i],
                    'mean wPLI por': mean_wPLI_por[i],
                    'SE wPLI por': mean_SEwPLI_por[i],
                    'mean wPLI tor': mean_wPLI_tor[i],
                    'SE wPLI tor': mean_SEwPLI_tor[i],
                    'mean DSPLI por': mean_DSPLI_por[i],
                    'SE DSPLI por': mean_SEDSPLI_por[i],
                    'mean DSPLI tor': mean_DSPLI_tor[i],
                    'SE DSPLI tor': mean_SEDSPLI_tor[i],
                    'mean wDSPLI por': mean_wDSPLI_por[i],
                    'SE wDSPLI por': mean_SEwDSPLI_por[i],
                    'mean wDSPLI tor': mean_wDSPLI_tor[i],
                    'SE wDSPLI tor': mean_SEwDSPLI_tor[i],
                    'mean PPC por': mean_PPC_por[i],
                    'SE PPC por': mean_SEPPC_por[i],
                    'mean PPC tor': mean_PPC_tor[i],
                    'SE PPC tor': mean_SEPPC_tor[i],

                    ' mean COH ALLP': mean_COH_ALLP[i],
                    'SE COH ALLP': mean_SECOH_ALLP[i],
                    ' mean COH ALLT': mean_COH_ALLT[i],
                    'SE COH ALLT': mean_SECOH_ALLT[i],
                    'mean iCOH ALLP': mean_iCOH_ALLP[i],
                    'SE iCOH ALLP': mean_SEiCOH_ALLP[i],
                    'mean iCOH ALLT': mean_iCOH_ALLT[i],
                    'SE iCOH ALLT': mean_SEiCOH_ALLT[i],
                    'mean PLI ALLP': mean_PLI_ALLP[i],
                    'SE PLI ALLP': mean_SEPLI_ALLP[i],
                    'mean PLI ALLT': mean_PLI_ALLT[i],
                    'SE PLI ALLT': mean_SEPLI_ALLT[i],
                    'mean wPLI ALLP': mean_wPLI_ALLP[i],
                    'SE wPLI ALLP': mean_SEwPLI_ALLP[i],
                    'mean wPLI ALLT': mean_wPLI_ALLT[i],
                    'SE wPLI ALLT': mean_SEwPLI_ALLT[i],
                    'mean DSPLI ALLP': mean_DSPLI_ALLP[i],
                    'SE DSPLI ALLP': mean_SEDSPLI_ALLP[i],
                    'mean DSPLI ALLT': mean_DSPLI_ALLT[i],
                    'SE DSPLI ALLT': mean_SEDSPLI_ALLT[i],
                    'mean wDSPLI ALLP': mean_wDSPLI_ALLP[i],
                    'SE wDSPLI ALLP': mean_SEwDSPLI_ALLP[i],
                    'mean wDSPLI ALLT': mean_wDSPLI_ALLT[i],
                    'SE wDSPLI ALLT': mean_SEwDSPLI_ALLT[i],
                    'mean PPC ALLP': mean_PPC_ALLP[i],
                    'SE PPC ALLP': mean_SEPPC_ALLP[i],
                    'mean PPC ALLT': mean_PPC_ALLT[i],
                    'SE PPC ALLT': mean_SEPPC_ALLT[i],

                })
df = pd.DataFrame(rows, index = ["delta (1-4 Hz)", "theta (5-12 Hz)", "alpha/beta (13-20 Hz)", "gamma (20-140 Hz)"])
df.to_csv('C:/Users/ejsev/Downloads/sleep scoring/table_results_means.csv', index=True)
df
# Out:
#                         mean COH pcn  SE COH pcn   mean COH tcn  SE COH tcn  \
# delta (1-4 Hz)              0.570620    0.023175       0.250784    0.016001
# theta (5-12 Hz)             0.574749    0.057586       0.303020    0.012357
# alpha/beta (13-20 Hz)       0.541666    0.036954       0.246390    0.013235
# gamma (20-140 Hz)           0.529403    0.043227       0.229215    0.017616
#
#                        mean iCOH pcn  SE iCOH pcn  mean iCOH tcn  SE iCOH tcn  \
# delta (1-4 Hz)              0.459243     0.038510       0.371178     0.008832
# theta (5-12 Hz)             0.524704     0.030594       0.448387     0.006140
# alpha/beta (13-20 Hz)       0.494234     0.013450       0.376105     0.011282
# gamma (20-140 Hz)           0.502525     0.013262       0.369864     0.009235
#
#                        mean PLI pcn  SE PLI pcn  ...  mean DSPLI ALLT  \
# delta (1-4 Hz)             0.007800    0.073574  ...         0.041895
# ...

# %%
rows = []
for i in range(4):
    rows.append({

                    ' mean COH ALLP': mean_COH_ALLP[i],
                    'SE COH ALLP': mean_SECOH_ALLP[i],
                    ' mean COH ALLT': mean_COH_ALLT[i],
                    'SE COH ALLT': mean_SECOH_ALLT[i],
                    'mean iCOH ALLP': mean_iCOH_ALLP[i],
                    'SE iCOH ALLP': mean_SEiCOH_ALLP[i],
                    'mean iCOH ALLT': mean_iCOH_ALLT[i],
                    'SE iCOH ALLT': mean_SEiCOH_ALLT[i],
                    'mean PLI ALLP': mean_PLI_ALLP[i],
                    'SE PLI ALLP': mean_SEPLI_ALLP[i],
                    'mean PLI ALLT': mean_PLI_ALLT[i],
                    'SE PLI ALLT': mean_SEPLI_ALLT[i],
                    'mean wPLI ALLP': mean_wPLI_ALLP[i],
                    'SE wPLI ALLP': mean_SEwPLI_ALLP[i],
                    'mean wPLI ALLT': mean_wPLI_ALLT[i],
                    'SE wPLI ALLT': mean_SEwPLI_ALLT[i],
                    'mean DSPLI ALLP': mean_DSPLI_ALLP[i],
                    'SE DSPLI ALLP': mean_SEDSPLI_ALLP[i],
                    'mean DSPLI ALLT': mean_DSPLI_ALLT[i],
                    'SE DSPLI ALLT': mean_SEDSPLI_ALLT[i],
                    'mean wDSPLI ALLP': mean_wDSPLI_ALLP[i],
                    'SE wDSPLI ALLP': mean_SEwDSPLI_ALLP[i],
                    'mean wDSPLI ALLT': mean_wDSPLI_ALLT[i],
                    'SE wDSPLI ALLT': mean_SEwDSPLI_ALLT[i],
                    'mean PPC ALLP': mean_PPC_ALLP[i],
                    'SE PPC ALLP': mean_SEPPC_ALLP[i],
                    'mean PPC ALLT': mean_PPC_ALLT[i],
                    'SE PPC ALLT': mean_SEPPC_ALLT[i],

                })
df2 = pd.DataFrame(rows, index = ["delta (1-4 Hz)", "theta (5-12 Hz)", "alpha/beta (13-20 Hz)", "gamma (20-140 Hz)"])
df2.to_csv('C:/Users/ejsev/Downloads/sleep scoring/table_results_means_ALL.csv', index=True)
df2
# Out:
#                         mean COH ALLP  SE COH ALLP   mean COH ALLT  \
# delta (1-4 Hz)               0.596069     0.009521        0.245368
# theta (5-12 Hz)              0.596877     0.017339        0.294175
# alpha/beta (13-20 Hz)        0.569244     0.013727        0.246951
# gamma (20-140 Hz)            0.563718     0.015799        0.230337
#
#                        SE COH ALLT  mean iCOH ALLP  SE iCOH ALLP  \
# delta (1-4 Hz)            0.009753        0.474924      0.011386
# theta (5-12 Hz)           0.006190        0.523810      0.010485
# alpha/beta (13-20 Hz)     0.006615        0.514260      0.006867
# gamma (20-140 Hz)         0.007036        0.511666      0.005351
#
#                        mean iCOH ALLT  SE iCOH ALLT  mean PLI ALLP  \
# delta (1-4 Hz)               0.366985      0.004988      -0.038442
# theta (5-12 Hz)              0.425051      0.008014       0.274643
# alpha/beta (13-20 Hz)        0.378656      0.004483       0.030746
# ...
